# %% [markdown]
# # Context
#
# In `make_synthetic_questions.ipynb`, we generated synthetic questions to bootstrap evaluation of the retrieval system in our hardware store's Q&A system.
#
# This notebook shows the first step in calculating precision and recall with different retrieval parameters. We will run more advanced experiments in future notebooks after we have these baseline scores.
#
# ## Data
#
# Here is a brief review of the data.

# %%
import json
import lancedb
import pandas as pd
from typing import List, Dict

pd.set_option("display.max_colwidth", 160)

db = lancedb.connect("./lancedb")
reviews_table = db.open_table("reviews")
reviews_table.to_pandas().head()
# Out:
#   id product_id  \
# 0  0          0
# 1  1          0
# 2  2          0
# 3  3          0
# 4  4          0
#
#                                                                                                                                                             review  \
# 0  This hammer has been a game-changer for my general carpentry work. The ergonomic grip is fantastic; it doesn't slip even when my hands are sweaty. The balan...
# 1  I've used many hammers over the years, but this one is easily the most comfortable. The handle has a great ergonomic design that reduces hand fatigue, even ...
# 2  This versatile claw hammer is a must-have for any DIY enthusiast. The grip is soft yet firm, making it easier to handle during extended projects. The balanc...
# 3  I've been using this hammer for home repairs, and it has exceeded my expectations. The ergonomic grip is cushioned and prevents blisters, which is a big plu...
# 4  This hammer ticks all the boxes for what I need in my toolkit. The ergonomic grip fits perfectly in my hand and reduces vibrations, which is essential for m...
#
#                                                                                                                                                             vector
# 0  [0.028299237, 0.040523008, -0.015594003, 0.018121675, 0.024046326, 0.023604987, -0.015166037, 0.023404378, 0.033060357, -0.021211054, 0.02139829, -0.0227490...
# 1  [0.040150184, 0.049218856, 0.0037333986, 0.02435106, 0.02382141, -0.0025449118, -0.015101533, 0.0005264221, 0.04064108, 0.0016567764, 0.018369872, -0.028627...
# 2  [0.02847098, 0.04930216, -0.0132550495, 0.014579281, 0.030482793, -0.0014380328, -0.021404168, 0.025045805, 0.0264337, -0.019099494, 0.023301383, -0.0213277...
# 3  [0.032133453, 0.04300249, 0.015580612, 0.027521593, 0.019880861, -0.014733027, -0.018484838, 0.015954547, 0.05053104, -0.02026726, 0.034925498, -0.010520029...
# 4  [0.0028318465, 0.059558474, -0.010654663, 0.01611974, 0.04999939, 0.01956665, -0.0065574544, 0.021219628, 0.0003812101, -0.0067977128, 0.039620224, -0.02911...

# %%
products_table = db.open_table("products")
products_table.to_pandas().head()
# Out:
#   id              title  \
# 0  0             Hammer
# 1  1     Cordless Drill
# 2  2  Adjustable Wrench
# 3  3    Screwdriver Set
# 4  4       Tape Measure
#
#                                                                                                                                         description  \
# 0  A versatile claw hammer for general carpentry and home repair. Features an ergonomic grip and balanced weight for efficient and comfortable use.
# 1  A powerful cordless drill with a rechargeable lithium-ion battery. Includes multiple drill bits and adjustable speed settings for various tasks.
# 2                        A durable adjustable wrench with a non-slip handle. Perfect for tightening or loosening nuts and bolts of different sizes.
# 3    A comprehensive screwdriver set that includes flathead, Phillips, and Torx drivers. Made from high-quality steel for long-lasting performance.
# 4         A 25-foot tape measure with a lockable blade and easy-to-read markings. Ideal for accurate measurements in construction and DIY projects.
#
#                                                                                                                                                             vector
# 0  [0.034557875, 0.0626897, 0.014434814, 0.007270958, 0.014863218, 0.0004704256, -0.037223496, 0.020837065, 0.025942206, -0.0033439265, 0.010721985, -0.0361048...
# 1  [0.0028601808, -0.008256353, -0.0016653886, -0.032711685, -0.00029657382, 0.012476035, -0.03971834, 0.06906264, 0.022567715, 0.010666853, 0.02626974, 0.0372...
# 2  [0.026549695, 0.027072059, -0.017692227, -0.024937183, -0.03470311, -0.013490607, 0.002430126, -0.02614089, -0.026095467, -0.013365693, 0.024006013, -0.0016...
# 3  [0.036627404, -0.014450144, -0.028289104, -0.033025783, 0.025975335, -0.045664202, 0.0013253696, 0.00069917855, 0.004864918, -0.02460017, 0.058761008, -0.00...
# 4  [0.048835468, 0.074131005, 0.0055233533, -0.030364534, -0.034419734, 0.019200375, -0.0253079, -0.059294913, 0.007121324, -7.2152085e-05, 0.011306338, -0.039...

# %%
with open("synthetic_eval_dataset.json", "r") as f:
    synthetic_questions = json.load(f)
synthetic_questions
# Out:
# [{'question': 'What feature of the Sawzall PX-1000 contributes to a secure hold during use?',
#   'answer': 'The ergonomic grip is designed to prevent slipping even when hands are sweaty.',
#   'chunk_id': '0'},
#  {'question': 'How has the Sawzall PX-1000 performed in terms of maintaining its condition over time?',
#   'answer': 'The product has remained in perfect condition after multiple heavy-duty projects over a period of six months.',
#   'chunk_id': '0'},
#  {'question': 'What feature of the Sawzall PX-1000 contributes to comfort during extended use?',
#   'answer': 'The ergonomic design of the handle reduces hand fatigue, even after hours of use.',
#   'chunk_id': '1'},
#  {'question': 'How does the claw feature of the Sawzall PX-1000 perform when removing nails?',
#   'answer': 'The claw is sturdy and removes nails without bending them.',
#   'chunk_id': '1'},
#  {'question': "What is a notable feature of the Sawzall PX-1000's grip?",
#   'answer': 'The grip is soft yet firm, making it easier to handle during extended projects.',
#   'chunk_id': '2'},
#  {'question': 'How does the weight of the Sawzall PX-1000 affect its usability?',
#   'answer': 'The balanced weight means less force is required to use it, which is beneficial for users with conditions like arthritis.',
#   'chunk_id': '2'},
#  {'question': 'What feature of the Sawzall PX-1000 prevents blisters during use?',
#   'answer': 'The ergonomic grip is cushioned, preventing blisters.',
#   'chunk_id': '3'},
#  {'question': 'How is the balance of the Sawzall PX-1000 described?',
#   'answer': 'The hammer is well-balanced, making it effective for both driving and removing nails.',
#   'chunk_id': '3'},
#  {'question': 'What feature of the Sawzall PX-1000 helps reduce user fatigue during use?',
#   'answer': 'The ergonomic grip fits perfectly in the hand and reduces vibrations.',
#   'chunk_id': '4'},
#  {'question': 'How does the claw part of the Sawzall PX-1000 perform in removing nails?',
#   'answer': 'The claw part is robust and pulls out nails effortlessly.',
#   'chunk_id': '4'},
#  {'question': "What is a notable feature of the Sawzall PX-1000's grip?",
#   'answer': 'The Sawzall PX-1000 has an ergonomic grip that makes it comfortable to use throughout the day.',
#   'chunk_id': '5'},
#  {'question': 'How does the claw of the Sawzall PX-1000 perform with nails?',
#   'answer': 'The claw is well-designed; it grips nails firmly and removes them without damaging the wood.',
#   'chunk_id': '5'},
#  {'question': 'What innovative feature does the Sawzall PX-1000 have for user comfort?',
#   'answer': 'The Sawzall PX-1000 has an ergonomic grip that makes it easy to hold.',
#   'chunk_id': '6'},
#  {'question': 'How does the weight of the Sawzall PX-1000 affect usability?',
#   'answer': 'The balanced weight of the Sawzall PX-1000 means users do not get tired as quickly.',
#   'chunk_id': '6'},
#  {'question': 'How does the ergonomic grip of the Sawzall PX-1000 perform during extended use?',
#   'answer': 'The ergonomic grip is very comfortable, even after hours of hammering.',
#   'chunk_id': '7'},
#  {'question': 'What features contribute to the ease of use of the Sawzall PX-1000?',
#   'answer': 'The balanced weight makes it easy to use without straining the arm.',
#   'chunk_id': '7'},
#  {'question': 'How long does the battery last during use?',
#   'answer': 'The lithium-ion battery lasts through multiple projects.',
#   'chunk_id': '8'},
#  {'question': 'What feature of the drill helps reduce hand fatigue?',
#   'answer': 'The ergonomic handle minimizes hand fatigue, even during prolonged use.',
#   'chunk_id': '8'},
#  {'question': 'What features does the Sawzall PX-1000 come with for versatility?',
#   'answer': 'The Sawzall PX-1000 comes with a variety of drill bits, suitable for different tasks like drilling, screwing, and mixing paint.',
#   'chunk_id': '9'},
#  {'question': 'How does the Sawzall PX-1000 perform in terms of usability in low light conditions?',
#   'answer': 'The Sawzall PX-1000 includes an LED light, making it easy to work in dimly lit areas.',
#   'chunk_id': '9'},
#  {'question': 'What is a notable feature of the Sawzall PX-1000 regarding its performance?',
#   'answer': 'The Sawzall PX-1000 is powerful enough to go through concrete walls with ease.',
#   'chunk_id': '10'},
#  {'question': 'How does the Sawzall PX-1000 support precision in various tasks?',
#   'answer': 'The speed settings of the Sawzall PX-1000 allow for precise control, making it ideal for delicate tasks.',
#   'chunk_id': '10'},
#  {'question': "What is highlighted as a key benefit of the Sawzall PX-1000's design?",
#   'answer': 'The Sawzall PX-1000 is compact but powerful.',
#   'chunk_id': '11'},
#  {'question': "What feature contributes to the Sawzall PX-1000's usability for various tasks?",
#   'answer': 'The adjustable speed settings make it versatile for different projects.',
#   'chunk_id': '11'},
#  {'question': 'What type of battery does the Sawzall PX-1000 use, and what is its performance like?',
#   'answer': 'The Sawzall PX-1000 uses a lithium-ion battery, which is very efficient and holds a charge for a long period.',
#   'chunk_id': '12'},
#  {'question': 'What features of the Sawzall PX-1000 enhance its usability during woodworking projects?',
#   'answer': 'The Sawzall PX-1000 includes multiple drill bits that cover almost every need, and it allows for smooth and easy switching between speeds for different materials.',
#   'chunk_id': '12'},
#  {'question': 'What notable feature does the Sawzall PX-1000 have regarding battery performance?',
#   'answer': 'The battery life is exceptional, allowing multiple tasks to be completed without needing a recharge.',
#   'chunk_id': '13'},
#  {'question': 'What type of drill bits are included with the Sawzall PX-1000?',
#   'answer': 'The included drill bits are very durable and versatile.',
#   'chunk_id': '13'},
#  {'question': 'What are the key features of the Sawzall PX-1000?',
#   'answer': 'The Sawzall PX-1000 is lightweight, robust, has adjustable speed settings, and comes with useful drill bits for various tasks including masonry and woodwork.',
#   'chunk_id': '14'},
#  {'question': 'How does the battery performance of the Sawzall PX-1000 rate?',
#   'answer': 'The lithium-ion battery of the Sawzall PX-1000 charges quickly and holds a charge well, even under heavy use.',
#   'chunk_id': '14'},
#  {'question': 'What feature of the Sawzall PX-1000 contributes to its usability for extended periods?',
#   'answer': 'The ergonomic design makes it very comfortable to hold and use for extended periods.',
#   'chunk_id': '15'},
#  {'question': 'How does the adjustable speed setting benefit users of the Sawzall PX-1000?',
#   'answer': 'The adjustable speed settings make it easy to switch between tasks without losing momentum.',
#   'chunk_id': '15'},
#  {'question': 'What feature of the Sawzall PX-1000 enhances user comfort during operation?',
#   'answer': 'The non-slip handle provides excellent grip even when hands are sweaty.',
#   'chunk_id': '16'},
#  {'question': 'How does the Sawzall PX-1000 perform with regards to adjusting for different sizes?',
#   'answer': 'The wrench adjusts smoothly, allowing it to tackle various sizes of nuts and bolts with ease.',
#   'chunk_id': '16'},
#  {'question': 'What feature of the Sawzall PX-1000 contributes to reducing hand fatigue?',
#   'answer': 'The ergonomic design of the non-slip handle provides comfort during prolonged use, reducing hand fatigue significantly.',
#   'chunk_id': '17'},
#  {'question': 'How does the adjustable mechanism of the Sawzall PX-1000 perform with different bolt sizes?',
#   'answer': 'The adjustable mechanism is precise and stays in place without slipping, which is crucial when working on different-sized bolts.',
#   'chunk_id': '17'},
#  {'question': 'What feature of the Sawzall PX-1000 provides excellent control in wet conditions?',
#   'answer': 'The non-slip handle offers excellent control, especially in wet conditions.',
#   'chunk_id': '18'},
#  {'question': 'How does the Sawzall PX-1000 compare in weight to its durability?',
#   'answer': 'It is surprisingly lightweight for its durability, making it comfortable to use for extended periods.',
#   'chunk_id': '18'},
#  {'question': 'What feature of the Sawzall PX-1000 helps maintain grip during use?',
#   'answer': 'The non-slip handle provides a firm grip, even when hands are greasy.',
#   'chunk_id': '19'},
#  {'question': 'How does the adjustment dial function on the Sawzall PX-1000?',
#   'answer': 'The adjustment dial is smooth and accurate, ensuring a tight fit on various bolt sizes.',
#   'chunk_id': '19'},
#  {'question': 'What feature of the Sawzall PX-1000 enhances grip and torque application?',
#   'answer': 'The non-slip handle enhances grip and torque application.',
#   'chunk_id': '20'},
#  {'question': 'How well does the Sawzall PX-1000 maintain its adjustment setting?',
#   'answer': 'The Sawzall PX-1000 holds its setting well, reducing the need for constant readjustment.',
#   'chunk_id': '20'},
#  {'question': 'What feature of the Sawzall PX-1000 enhances safety during use?',
#   'answer': 'The non-slip handle is incredibly comfortable and prevents any accidental slips, which is a huge plus for safety.',
#   'chunk_id': '21'},
#  {'question': 'How does the Sawzall PX-1000 perform on different tasks?',
#   'answer': 'The wrench adjusts smoothly and locks securely in place, making it easy to use on a variety of bolts and has performed flawlessly for tasks ranging from car repairs to assembling furniture.',
#   'chunk_id': '21'},
#  {'question': 'What feature ensures a steady grip on the Sawzall PX-1000?',
#   'answer': 'The non-slip handle ensures a steady grip.',
#   'chunk_id': '22'},
#  {'question': 'How does the jaw of the Sawzall PX-1000 accommodate different bolt sizes?',
#   'answer': 'The adjustable jaw moves seamlessly to accommodate different bolt sizes.',
#   'chunk_id': '22'},
#  {'question': 'What feature of the Sawzall PX-1000 ensures comfort during extended use?',
#   'answer': 'The non-slip handle is comfortable, allowing for prolonged use without hand strain.',
#   'chunk_id': '23'},
#  {'question': 'How does the adjustment mechanism of the Sawzall PX-1000 perform?',
#   'answer': 'The adjustment mechanism is precise and stays firmly in place during use, which is crucial for efficiency and safety.',
#   'chunk_id': '23'},
#  {'question': 'What types of drivers are included in the Sawzall PX-1000 screwdriver set?',
#   'answer': 'The set includes various sizes of flathead, Phillips, and Torx drivers.',
#   'chunk_id': '24'},
#  {'question': 'What material is the Sawzall PX-1000 screwdriver set made of?',
#   'answer': 'The screwdriver set is made of high-quality steel construction.',
#   'chunk_id': '24'},
#  {'question': 'What types of drivers are included in the Sawzall PX-1000 screwdriver set?',
#   'answer': 'The screwdriver set includes flathead, Phillips, and Torx drivers.',
#   'chunk_id': '25'},
#  {'question': 'What feature of the Sawzall PX-1000 helps in placing screws in tight areas?',
#   'answer': 'The screwdriver set has magnetic tips that make it easier to get screws in tight spots.',
#   'chunk_id': '25'},
#  {'question': 'What material is used for the screwdriver drivers in the Sawzall PX-1000?',
#   'answer': 'The screwdriver drivers are made from high-quality steel that is tough and resistant to wear and tear.',
#   'chunk_id': '26'},
#  {'question': 'What features does the carrying case of the Sawzall PX-1000 provide?',
#   'answer': 'The carrying case keeps everything organized, making it a convenient feature of the set.',
#   'chunk_id': '26'},
#  {'question': 'What materials are the screwdriver drivers made from?',
#   'answer': 'The screwdriver drivers are made from high-quality steel.',
#   'chunk_id': '27'},
#  {'question': 'How do the handles of the screwdriver set perform during use?',
#   'answer': 'The handles are designed to provide a good grip, and there is no slippage experienced.',
#   'chunk_id': '27'},
#  {'question': 'What types of drivers are included in the Sawzall PX-1000 screwdriver set?',
#   'answer': 'The screwdriver set includes flathead, Phillips, and Torx drivers.',
#   'chunk_id': '28'},
#  {'question': 'What feature of the Sawzall PX-1000 helps reduce hand fatigue during use?',
#   'answer': 'The screwdriver set has ergonomic handles that reduce hand fatigue.',
#   'chunk_id': '28'},
#  {'question': 'What materials are the drivers in the Sawzall PX-1000 made from?',
#   'answer': 'The drivers are made from high-quality steel.',
#   'chunk_id': '29'},
#  {'question': 'How do the ergonomic handles of the Sawzall PX-1000 contribute to its usability?',
#   'answer': 'The ergonomic handles are comfortable to hold and provide excellent control.',
#   'chunk_id': '29'},
#  {'question': 'What materials are used in the construction of the Sawzall PX-1000 screwdriver set?',
#   'answer': 'The screwdriver set is made of high-quality steel, offering excellent durability.',
#   'chunk_id': '30'},
#  {'question': 'What features help in handling screws more easily with the Sawzall PX-1000?',
#   'answer': 'The set includes magnetic tips, which make handling screws much easier, especially in tight spots.',
#   'chunk_id': '30'},
#  {'question': 'What material is used for the construction of the Sawzall PX-1000 drivers?',
#   'answer': 'The drivers are made of high-quality steel.',
#   'chunk_id': '31'},
#  {'question': 'What feature helps to prevent screws from falling when using the Sawzall PX-1000 drivers?',
#   'answer': 'The drivers have magnetic tips.',
#   'chunk_id': '31'},
#  {'question': 'What is the length of the Sawzall PX-1000 tape measure?',
#   'answer': 'The length of the Sawzall PX-1000 tape measure is 25 feet.',
#   'chunk_id': '32'},
#  {'question': 'What feature helps prevent the blade from slipping during measurements?',
#   'answer': 'The lockable blade feature helps prevent the blade from slipping during measurements.',
#   'chunk_id': '32'},
#  {'question': 'What feature of the Sawzall PX-1000 makes measuring easier?',
#   'answer': 'The lockable blade makes measuring so much easier.',
#   'chunk_id': '33'},
#  {'question': 'How durable is the body of the Sawzall PX-1000?',
#   'answer': 'The body of the tape measure is rugged and has survived multiple drops without any issues.',
#   'chunk_id': '33'},
#  {'question': 'How durable is the blade of the Sawzall PX-1000?',
#   'answer': "The blade is strong and doesn't bend easily, making it suitable for measuring long distances.",
#   'chunk_id': '34'},
#  {'question': 'What feature enhances the accuracy of measurements with the Sawzall PX-1000?',
#   'answer': 'The hook at the end catches onto surfaces firmly, which helps in getting an accurate start.',
#   'chunk_id': '34'},
#  {'question': 'What is the length of the Sawzall PX-1000 tape measure?',
#   'answer': 'The Sawzall PX-1000 tape measure has a length of 25 feet.',
#   'chunk_id': '35'},
#  {'question': 'What feature of the Sawzall PX-1000 ensures accuracy in measurements?',
#   'answer': 'The Sawzall PX-1000 has a lockable blade that ensures measurements stay accurate.',
#   'chunk_id': '35'},
#  {'question': 'What is a notable feature of the Sawzall PX-1000 regarding its length?',
#   'answer': 'The Sawzall PX-1000 has a 25-foot length that covers pretty much any job.',
#   'chunk_id': '36'},
#  {'question': 'How does the Sawzall PX-1000 ensure precision in measurements?',
#   'answer': 'The Sawzall PX-1000 features a lockable blade that allows for precise measurements without constant readjustment.',
#   'chunk_id': '36'},
#  {'question': 'How does the blade of the Sawzall PX-1000 perform during use?',
#   'answer': 'The blade locks securely, which is great for measuring long pieces of lumber.',
#   'chunk_id': '37'},
#  {'question': 'What features contribute to the usability of the Sawzall PX-1000?',
#   'answer': 'The easy-to-read markings save time and help avoid squinting and double-checking.',
#   'chunk_id': '37'},
#  {'question': 'What is a key feature that makes the Sawzall PX-1000 easy to find?',
#   'answer': 'The bright color of the Sawzall PX-1000 makes it harder to lose.',
#   'chunk_id': '38'},
#  {'question': 'What feature enhances the usability of the Sawzall PX-1000 for construction projects?',
#   'answer': 'The Sawzall PX-1000 has a 25-foot length and a lockable blade.',
#   'chunk_id': '38'},
#  {'question': "What is highlighted about the Sawzall PX-1000's build quality?",
#   'answer': 'The Sawzall PX-1000 has a top-notch build quality with a reinforced case that seems nearly unbreakable.',
#   'chunk_id': '39'},
#  {'question': 'What feature of the blade is mentioned regarding its reach?',
#   'answer': 'The Sawzall PX-1000 has a 25-foot blade that provides ample reach for various tasks.',
#   'chunk_id': '39'},
#  {'question': 'What features of the Sawzall PX-1000 enhance its cutting performance?',
#   'answer': 'The powerful motor and laser guide enhance cutting performance, making it easy to cut through wood, metal, and plastic while ensuring precise cuts.',
#   'chunk_id': '40'},
#  {'question': "How does the Sawzall PX-1000's build quality impact its longevity?",
#   'answer': 'The top-notch build quality gives confidence that the Sawzall PX-1000 will last for years.',
#   'chunk_id': '40'},
#  {'question': 'What features enhance the versatility of the Sawzall PX-1000?',
#   'answer': 'The Sawzall PX-1000 has adjustable depth settings that enhance its versatility.',
#   'chunk_id': '41'},
#  {'question': 'How does the Sawzall PX-1000 perform with different materials?',
#   'answer': 'The Sawzall PX-1000 can cut through various materials, including thick oak boards and aluminum sheets, without any issues.',
#   'chunk_id': '41'},
#  {'question': 'What feature helps with making straight cuts in the Sawzall PX-1000?',
#   'answer': 'The laser guide helps with making straight cuts.',
#   'chunk_id': '42'},
#  {'question': 'What materials can the Sawzall PX-1000 cut through?',
#   'answer': 'It can cut through plywood, metal pipes, and plastic tubing.',
#   'chunk_id': '42'},
#  {'question': 'What feature of the Sawzall PX-1000 helps ensure accurate cuts?',
#   'answer': 'The laser guide ensures accurate cuts.',
#   'chunk_id': '43'},
#  {'question': 'How does the Sawzall PX-1000 perform on different materials?',
#   'answer': 'It can cut hardwood to PVC without any issues.',
#   'chunk_id': '43'},
#  {'question': 'What is a notable feature of the Sawzall PX-1000 that aids in making precise cuts?',
#   'answer': 'The Sawzall PX-1000 has a laser guide that is extremely helpful for making precise cuts.',
#   'chunk_id': '44'},
#  {'question': 'How does the Sawzall PX-1000 perform when cutting through different materials?',
#   'answer': 'The Sawzall PX-1000 slices through wood, metal, and plastic like butter.',
#   'chunk_id': '44'},
#  {'question': 'What feature of the Sawzall PX-1000 helps achieve straight cuts?',
#   'answer': 'The laser guide is a feature that helps achieve straight cuts.',
#   'chunk_id': '45'},
#  {'question': 'What aspect of the Sawzall PX-1000 provides versatility in different project sizes?',
#   'answer': 'The adjustable depth settings provide versatility for large construction projects or small DIY tasks.',
#   'chunk_id': '45'},
#  {'question': 'What features make the Sawzall PX-1000 effective for cutting various materials?',
#   'answer': 'The Sawzall PX-1000 has a high-powered motor, a precise laser guide for straight lines, and adjustable depth settings, making it effective for cutting through various materials.',
#   'chunk_id': '46'},
#  {'question': 'How does the construction quality of the Sawzall PX-1000 contribute to its usability?',
#   'answer': 'The Sawzall PX-1000 is well-constructed and durable, which enhances its safety and reliability during use.',
#   'chunk_id': '46'},
#  {'question': 'What feature of the Sawzall PX-1000 aids in making accurate cuts?',
#   'answer': 'The laser guide helps to make very accurate cuts.',
#   'chunk_id': '47'},
#  {'question': 'What types of materials can the Sawzall PX-1000 cut through?',
#   'answer': 'It can cut through hardwood, metal sheets, and plastic boards.',
#   'chunk_id': '47'},
#  {'question': 'What is the length of the Sawzall PX-1000 and what is its significance?',
#   'answer': 'The Sawzall PX-1000 is 24 inches long, which is perfect for both big and small jobs.',
#   'chunk_id': '48'},
#  {'question': 'What features of the Sawzall PX-1000 contribute to its accuracy?',
#   'answer': 'The Sawzall PX-1000 has three vials that make it easy to achieve precise horizontal, vertical, and 45-degree angles.',
#   'chunk_id': '48'},
#  {'question': 'What material is the Sawzall PX-1000 made from?',
#   'answer': 'The Sawzall PX-1000 is made of durable, lightweight aluminum.',
#   'chunk_id': '49'},
#  {'question': 'What feature of the Sawzall PX-1000 aids in measuring angled corners?',
#   'answer': 'The 45-degree vial is especially helpful for measuring angled corners.',
#   'chunk_id': '49'},
#  {'question': 'What is the size of the Sawzall PX-1000 and how does it benefit its use?',
#   'answer': 'The Sawzall PX-1000 has a 24-inch size, which is great for door frames and shelves.',
#   'chunk_id': '50'},
#  {'question': 'How does the visibility of the bubble indicators perform in various lighting conditions?',
#   'answer': 'The bubble indicators are spot-on and easy to see even in low light.',
#   'chunk_id': '50'},
#  {'question': 'What aspect of the Sawzall PX-1000 contributes to its accuracy?',
#   'answer': 'The precision of the vials is amazing, and it stays accurate even after rough handling.',
#   'chunk_id': '51'},
#  {'question': 'What is a notable feature of the Sawzall PX-1000 regarding its physical dimensions?',
#   'answer': 'The 24-inch length is just right for most tasks around the house.',
#   'chunk_id': '51'},
#  {'question': 'What is the length of the Sawzall PX-1000 and how does it benefit its use?',
#   'answer': 'The Sawzall PX-1000 has a 24-inch length, which is ideal for a wide range of applications.',
#   'chunk_id': '52'},
#  {'question': 'What features contribute to the durability and usability of the Sawzall PX-1000?',
#   'answer': 'The Sawzall PX-1000 has a robust yet lightweight body and rubber end caps that prevent slipping.',
#   'chunk_id': '52'},
#  {'question': 'What size is the Sawzall PX-1000, and how does it affect measurement accuracy?',
#   'answer': 'The Sawzall PX-1000 is 24 inches long, and its size, along with three vials, provides confidence in precise measurements.',
#   'chunk_id': '53'},
#  {'question': 'How is the frame of the Sawzall PX-1000 described in terms of weight and handling?',
#   'answer': 'The frame of the Sawzall PX-1000 is described as strong but not too heavy, making it easy to handle.',
#   'chunk_id': '53'},
#  {'question': 'What material is the Sawzall PX-1000 made of?',
#   'answer': 'The Sawzall PX-1000 is made of aluminum, which is both durable and lightweight.',
#   'chunk_id': '54'},
#  {'question': 'What types of vials does the Sawzall PX-1000 have?',
#   'answer': 'The Sawzall PX-1000 has horizontal, vertical, and 45-degree vials that are highly accurate.',
#   'chunk_id': '54'},
#  {'question': 'What feature of the Sawzall PX-1000 enhances its accuracy?',
#   'answer': 'The accuracy of the three vials helps ensure tiles are perfectly aligned.',
#   'chunk_id': '55'},
#  {'question': 'What aspect of the Sawzall PX-1000 contributes to its sturdiness?',
#   'answer': 'The craftsmanship is evident in how sturdy it feels.',
#   'chunk_id': '55'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for versatility in nail sizes?',
#   'answer': 'The adjustable pressure settings allow the use of different nail sizes with ease.',
#   'chunk_id': '56'},
#  {'question': 'How does the ergonomic design of the Sawzall PX-1000 benefit its user?',
#   'answer': 'The ergonomic design allows for prolonged use without experiencing hand fatigue.',
#   'chunk_id': '56'},
#  {'question': 'What features of the Sawzall PX-1000 enhance its usability for DIY projects?',
#   'answer': 'The Sawzall PX-1000 is compatible with a range of nail sizes and has a quick-release magazine, which enhances its usability for both detailed work and heavy-duty tasks.',
#   'chunk_id': '57'},
#  {'question': 'How does the Sawzall PX-1000 perform in terms of reliability?',
#   'answer': 'The Sawzall PX-1000 has not experienced any jams even after extensive use, indicating high reliability.',
#   'chunk_id': '57'},
#  {'question': 'What is a notable feature of the power of the Sawzall PX-1000?',
#   'answer': 'The power of the Sawzall PX-1000 ensures that nails are driven in flush every time, regardless of the material.',
#   'chunk_id': '58'},
#  {'question': 'How does the Sawzall PX-1000 perform in terms of durability?',
#   'answer': 'The casing of the Sawzall PX-1000 is robust and has survived multiple drops without any issues.',
#   'chunk_id': '58'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for control over nail depth?',
#   'answer': 'The depth adjustment feature.',
#   'chunk_id': '59'},
#  {'question': 'What is a notable physical attribute of the Sawzall PX-1000 mentioned in the review?',
#   'answer': 'It is surprisingly lightweight for a pneumatic tool.',
#   'chunk_id': '59'},
#  {'question': 'What features of the Sawzall PX-1000 enhance its efficiency?',
#   'answer': 'The Sawzall PX-1000 features quick and accurate nail firing, which enhances its efficiency in nailing tasks.',
#   'chunk_id': '60'},
#  {'question': 'What safety feature does the Sawzall PX-1000 include?',
#   'answer': 'The Sawzall PX-1000 includes a safety lock mechanism that provides peace of mind when it is not in use.',
#   'chunk_id': '60'},
#  {'question': 'How well does the Sawzall PX-1000 perform during renovations?',
#   'answer': 'The Sawzall PX-1000 performs outstandingly, handling everything from framing to trim work effectively.',
#   'chunk_id': '61'},
#  {'question': 'What feature of the Sawzall PX-1000 ensures reliability during use?',
#   'answer': 'The air connector fits securely, preventing leakage, which is a common issue in cheaper models.',
#   'chunk_id': '61'},
#  {'question': 'What mechanism does the Sawzall PX-1000 include to enhance safety?',
#   'answer': 'The Sawzall PX-1000 includes an anti-dry fire mechanism, which prevents the gun from firing when the magazine is empty.',
#   'chunk_id': '62'},
#  {'question': 'What makes the Sawzall PX-1000 a good investment for toolkits?',
#   'answer': 'The Sawzall PX-1000 is versatile and works well with both small and large nails, making it a valuable addition to any serious toolkit.',
#   'chunk_id': '62'},
#  {'question': 'What is a notable feature of the Sawzall PX-1000 regarding its operation?',
#   'answer': 'The pneumatic action is smooth and consistently drives nails to the perfect depth.',
#   'chunk_id': '63'},
#  {'question': 'How does the design of the Sawzall PX-1000 affect user comfort during extended use?',
#   'answer': 'The balance and weight distribution are excellent, reducing wrist strain.',
#   'chunk_id': '63'},
#  {'question': 'How powerful is the Sawzall PX-1000 when used on tough materials?',
#   'answer': 'The motor does not stall even when tackling tough metal surfaces.',
#   'chunk_id': '64'},
#  {'question': 'What feature of the Sawzall PX-1000 contributes to its safety during use?',
#   'answer': 'The adjustable guard makes it safer to use in various positions.',
#   'chunk_id': '64'},
#  {'question': 'What performance characteristics does the Sawzall PX-1000 demonstrate?',
#   'answer': 'The Sawzall PX-1000 has a smooth-running motor and can handle both grinding and polishing jobs effortlessly.',
#   'chunk_id': '65'},
#  {'question': 'What feature of the Sawzall PX-1000 enhances its usability for precise tasks?',
#   'answer': 'The adjustable guard is a game-changer for achieving precision.',
#   'chunk_id': '65'},
#  {'question': 'What is a key feature of the Sawzall PX-1000 that enhances safety?',
#   'answer': 'The adjustable guard provides much-needed safety features.',
#   'chunk_id': '66'},
#  {'question': 'In what materials can the Sawzall PX-1000 be effectively used?',
#   'answer': 'The Sawzall PX-1000 can easily cut through both metal and thick stone slabs.',
#   'chunk_id': '66'},
#  {'question': 'What is a notable feature of the Sawzall PX-1000 in terms of performance?',
#   'answer': 'The motor is impressively powerful and doesn’t overheat during prolonged use.',
#   'chunk_id': '67'},
#  {'question': 'How does the adjustable guard of the Sawzall PX-1000 perform?',
#   'answer': 'The adjustable guard is easy to manipulate and stays in place.',
#   'chunk_id': '67'},
#  {'question': 'How does the motor of the Sawzall PX-1000 perform during extended use?',
#   'answer': 'The motor is powerful enough to handle extended use without losing efficiency.',
#   'chunk_id': '68'},
#  {'question': 'What feature of the Sawzall PX-1000 aids in performing precise work?',
#   'answer': 'The adjustable guard is particularly handy for precise work around edges.',
#   'chunk_id': '68'},
#  {'question': 'What is a notable feature of the Sawzall PX-1000 regarding its performance?',
#   'answer': 'The Sawzall PX-1000 has powerful capabilities that allow it to cut metal and grind down welds easily.',
#   'chunk_id': '69'},
#  {'question': 'What is mentioned about the design of the Sawzall PX-1000?',
#   'answer': 'The Sawzall PX-1000 is bulkier than other models, but this bulkiness is considered a worthwhile trade-off for its performance.',
#   'chunk_id': '69'},
#  {'question': 'What feature of the Sawzall PX-1000 enhances safety during use?',
#   'answer': 'The adjustable guard adds an extra layer of safety.',
#   'chunk_id': '70'},
#  {'question': 'How does the noise level of the Sawzall PX-1000 compare to expectations?',
#   'answer': 'It’s slightly louder than expected.',
#   'chunk_id': '70'},
#  {'question': 'What is a notable feature of the Sawzall PX-1000 for metalworking?',
#   'answer': 'The powerful motor that cuts through metal easily.',
#   'chunk_id': '71'},
#  {'question': 'What is a drawback of the Sawzall PX-1000 as mentioned in the review?',
#   'answer': 'It is a bit on the heavier side, making it less ideal for prolonged use without breaks.',
#   'chunk_id': '71'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for quick access to a sharp edge?',
#   'answer': 'The Sawzall PX-1000 has a retractable blade feature that allows users to snap off blade segments to get a fresh, sharp edge quickly.',
#   'chunk_id': '72'},
#  {'question': 'How does the safety lock of the Sawzall PX-1000 enhance user security?',
#   'answer': 'The robust safety lock of the Sawzall PX-1000 provides peace of mind when carrying it in a pocket or tool belt.',
#   'chunk_id': '72'},
#  {'question': 'What feature of the Sawzall PX-1000 ensures a consistently sharp edge during use?',
#   'answer': 'The snap-off blade feature allows for a consistently sharp edge.',
#   'chunk_id': '73'},
#  {'question': 'What design aspect of the Sawzall PX-1000 contributes to comfort during extended use?',
#   'answer': 'The ergonomic handle design contributes to comfort during extended use.',
#   'chunk_id': '73'},
#  {'question': 'What is a notable feature of the blade change mechanism of the Sawzall PX-1000?',
#   'answer': 'The blade changes are quick and safe thanks to the snap-off design.',
#   'chunk_id': '74'},
#  {'question': 'How does the retractable blade mechanism function in the Sawzall PX-1000?',
#   'answer': 'The retractable blade mechanism works smoothly and the safety lock clicks into place securely every time.',
#   'chunk_id': '74'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for a fresh cutting edge?',
#   'answer': 'The snap-off blade feature provides a fresh cutting edge without the need for additional tools.',
#   'chunk_id': '75'},
#  {'question': 'How does the safety lock of the Sawzall PX-1000 enhance its usability?',
#   'answer': 'The safety lock is extremely reliable, preventing accidental extensions while in storage.',
#   'chunk_id': '75'},
#  {'question': 'What makes the retractable blade of the Sawzall PX-1000 convenient?',
#   'answer': 'The retractable blade is convenient and safe to use, especially with the added safety lock.',
#   'chunk_id': '76'},
#  {'question': 'How does the blade design of the Sawzall PX-1000 benefit its longevity?',
#   'answer': 'The snap-off blade segments extend the life of the blade significantly, contributing to cost-saving.',
#   'chunk_id': '76'},
#  {'question': 'What feature of the Sawzall PX-1000 helps maintain blade sharpness?',
#   'answer': 'The snap-off blade stays sharp for a long time.',
#   'chunk_id': '77'},
#  {'question': 'What safety mechanism does the Sawzall PX-1000 have to prevent accidents?',
#   'answer': 'The safety lock is very effective.',
#   'chunk_id': '77'},
#  {'question': 'What feature of the Sawzall PX-1000 ensures the blade stays secure during use?',
#   'answer': 'The safety lock holds the blade firmly in place.',
#   'chunk_id': '78'},
#  {'question': 'What advantage does the snap-off blade provide for users?',
#   'answer': 'The snap-off blade eliminates the need for frequent sharpening or replacing dull blades.',
#   'chunk_id': '78'},
#  {'question': 'What feature of the Sawzall PX-1000 ensures a consistently sharp edge?',
#   'answer': "The snap-off blade feature ensures you'll always have a sharp edge at the ready.",
#   'chunk_id': '79'},
#  {'question': 'How does the retractable blade mechanism of the Sawzall PX-1000 perform?',
#   'answer': 'The retractable blade mechanism is very smooth.',
#   'chunk_id': '79'},
#  {'question': 'What feature of the Sawzall PX-1000 helps in organizing tools and materials?',
#   'answer': 'The built-in storage shelves are incredibly convenient, allowing for efficient organization of tools and materials.',
#   'chunk_id': '80'},
#  {'question': 'How does the Sawzall PX-1000 perform under heavy loads?',
#   'answer': 'The workbench is very sturdy and can handle heavy loads without any wobbling.',
#   'chunk_id': '80'},
#  {'question': 'What features does the Sawzall PX-1000 offer for tool storage?',
#   'answer': "The Sawzall PX-1000 has built-in storage shelves that are perfect for keeping tools and supplies within arm's reach.",
#   'chunk_id': '81'},
#  {'question': 'How does the Sawzall PX-1000 perform on uneven surfaces?',
#   'answer': 'The Sawzall PX-1000 has adjustable feet that help keep the bench stable on uneven floors.',
#   'chunk_id': '81'},
#  {'question': 'What feature of the Sawzall PX-1000 provides ample storage without sacrificing workspace?',
#   'answer': 'The built-in shelves are a fantastic feature, providing ample storage without sacrificing work surface space.',
#   'chunk_id': '82'},
#  {'question': 'How does the height of the Sawzall PX-1000 contribute to its usability during long projects?',
#   'answer': "The workbench's height is perfect for standing work, reducing strain on the back during long projects.",
#   'chunk_id': '82'},
#  {'question': 'What materials are used in the construction of the Sawzall PX-1000 workbench?',
#   'answer': 'The workbench is constructed with heavy-duty materials that withstand daily use without showing signs of wear.',
#   'chunk_id': '83'},
#  {'question': 'How does the Sawzall PX-1000 support organization for tools?',
#   'answer': 'The workbench features multiple storage shelves that help keep tools organized.',
#   'chunk_id': '83'},
#  {'question': 'What feature of the Sawzall PX-1000 helps in organizing tools?',
#   'answer': 'The built-in storage is a practical feature that keeps essential tools within reach.',
#   'chunk_id': '84'},
#  {'question': 'How does the workbench perform under heavy loads?',
#   'answer': 'The workbench is very sturdy and supports heavy equipment without any issues.',
#   'chunk_id': '84'},
#  {'question': 'What features does the Sawzall PX-1000 have for tool organization?',
#   'answer': 'The Sawzall PX-1000 has built-in storage shelves that are incredibly useful for organizing hand tools, screws, and other small items.',
#   'chunk_id': '85'},
#  {'question': 'How stable is the Sawzall PX-1000 during use?',
#   'answer': 'The Sawzall PX-1000 has a sturdy frame and does not shake even when hammering or drilling.',
#   'chunk_id': '85'},
#  {'question': 'What features contribute to the stability of the Sawzall PX-1000?',
#   'answer': 'The Sawzall PX-1000 is stable due to its solid construction and weight distribution.',
#   'chunk_id': '86'},
#  {'question': 'How does the Sawzall PX-1000 enhance workspace organization?',
#   'answer': 'The Sawzall PX-1000 includes built-in shelves, providing more room to work without clutter.',
#   'chunk_id': '86'},
#  {'question': 'What features help keep the workspace organized with the Sawzall PX-1000?',
#   'answer': 'The Sawzall PX-1000 has built-in storage shelves that help keep the workspace tidy and tools organized.',
#   'chunk_id': '87'},
#  {'question': 'How does the surface of the Sawzall PX-1000 perform under pressure?',
#   'answer': 'The surface of the Sawzall PX-1000 is robust and provides a stable surface that doesn’t flex under pressure.',
#   'chunk_id': '87'},
#  {'question': 'How effective is the suction power of the Sawzall PX-1000?',
#   'answer': 'The powerful suction motor picks up everything from sawdust to small screws with ease.',
#   'chunk_id': '88'},
#  {'question': 'What feature of the Sawzall PX-1000 is beneficial for cleaning up liquids?',
#   'answer': 'The wet capability came in handy when my basement flooded last spring, speeding up the cleanup process significantly.',
#   'chunk_id': '88'},
#  {'question': 'What is the power of the Sawzall PX-1000 motor?',
#   'answer': 'The Sawzall PX-1000 features a 5.5 HP motor that delivers incredible suction power.',
#   'chunk_id': '89'},
#  {'question': 'What is the capacity of the tank on the Sawzall PX-1000?',
#   'answer': 'The Sawzall PX-1000 has a 12-gallon tank that is perfect for large messes.',
#   'chunk_id': '89'},
#  {'question': 'How effective is the Sawzall PX-1000 at cleaning up debris and dust?',
#   'answer': 'It effectively sucks up debris and drywall dust.',
#   'chunk_id': '90'},
#  {'question': 'What feature helps keep the attachments organized with the Sawzall PX-1000?',
#   'answer': 'The on-board storage for attachments is a helpful feature.',
#   'chunk_id': '90'},
#  {'question': 'What capacity does the Sawzall PX-1000 have?',
#   'answer': 'The Sawzall PX-1000 has a 14-gallon capacity.',
#   'chunk_id': '91'},
#  {'question': 'What are some notable features of the Sawzall PX-1000?',
#   'answer': 'The Sawzall PX-1000 is great for wet and dry messes, has a sturdy build quality, and comes with accessories like a crevice tool and floor nozzle that store neatly on the vacuum.',
#   'chunk_id': '91'},
#  {'question': 'What features of the Sawzall PX-1000 make it suitable for cleanup tasks?',
#   'answer': 'The Sawzall PX-1000 has strong suction power to pick up wood shavings and metal filings, a wet feature for cleaning up spills, and a blower function for clearing dust.',
#   'chunk_id': '92'},
#  {'question': 'How does the design of the Sawzall PX-1000 contribute to its usability?',
#   'answer': 'The setup of the Sawzall PX-1000 is straightforward, and it feels durable, indicating that it is made to last for years.',
#   'chunk_id': '92'},
#  {'question': 'What capabilities does the Sawzall PX-1000 have?',
#   'answer': 'The Sawzall PX-1000 has wet and dry capabilities.',
#   'chunk_id': '93'},
#  {'question': 'What features contribute to the convenience of the Sawzall PX-1000?',
#   'answer': 'The Sawzall PX-1000 has a strong motor, a 10-foot power cord for easy movement, an easy-to-empty and clean tank, and a filter that is simple to change.',
#   'chunk_id': '93'},
#  {'question': 'What is a key feature of the Sawzall PX-1000 that enhances its cleaning ability in automotive detailing?',
#   'answer': 'The powerful motor ensures that all dirt, grime, and even small gravel are picked up from car interiors.',
#   'chunk_id': '94'},
#  {'question': 'How does the design of the Sawzall PX-1000 facilitate its use in wet detailing?',
#   'answer': 'It efficiently extracts water from carpets and seats.',
#   'chunk_id': '94'},
#  {'question': 'What features does the Sawzall PX-1000 have for cleaning spills?',
#   'answer': 'The Sawzall PX-1000 has a wet feature that quickly deals with spills and messes.',
#   'chunk_id': '95'},
#  {'question': 'How does the Sawzall PX-1000 handle heavier debris?',
#   'answer': 'The dry function of the Sawzall PX-1000 is impressive, handling heavy debris without clogging.',
#   'chunk_id': '95'},
#  {'question': 'What feature of the Sawzall PX-1000 enhances its visibility in low light?',
#   'answer': 'The LED display is bright and easy to read, even in dimly lit rooms.',
#   'chunk_id': '96'},
#  {'question': 'What types of materials can the Sawzall PX-1000 detect?',
#   'answer': 'It accurately detects both wood and metal studs, making it versatile for various projects.',
#   'chunk_id': '96'},
#  {'question': 'What feature of the Sawzall PX-1000 enhances its reliability?',
#   'answer': 'The electronic detection is spot-on and has never given a false reading.',
#   'chunk_id': '97'},
#  {'question': 'How does the LED display contribute to the usability of the Sawzall PX-1000?',
#   'answer': 'The LED display is very detailed, showing not just the location of the stud but also its edges, making it easy to center nails and screws perfectly.',
#   'chunk_id': '97'},
#  {'question': 'What feature allows the Sawzall PX-1000 to detect different materials?',
#   'answer': 'The Sawzall PX-1000 easily switches between detecting wood and metal studs with a simple press of a button.',
#   'chunk_id': '98'},
#  {'question': 'How does the product indicate different types of materials?',
#   'answer': 'The product has audible alerts with different tones for different materials.',
#   'chunk_id': '98'},
#  {'question': "What features contribute to the Sawzall PX-1000's performance on different wall types?",
#   'answer': 'The Sawzall PX-1000 performs well on both drywall and plaster walls, with amazing accuracy in its measurements.',
#   'chunk_id': '99'},
#  {'question': 'What display features are included in the Sawzall PX-1000?',
#   'answer': 'The Sawzall PX-1000 includes an LED display that provides information such as depth readings and has audible alerts that enhance its usability.',
#   'chunk_id': '99'},
#  {'question': 'What feature of the Sawzall PX-1000 contributes to its ease of use during extended periods?',
#   'answer': 'The grip is ergonomically designed, making it comfortable to hold during extended use.',
#   'chunk_id': '100'},
#  {'question': 'How does the Sawzall PX-1000 enhance accuracy when detecting materials?',
#   'answer': 'It provides different audible alerts for wood and metal, adding a layer of confidence to the work.',
#   'chunk_id': '100'},
#  {'question': 'What features contribute to the ease of use of the Sawzall PX-1000?',
#   'answer': 'The LED display and audible alerts simplify the process of finding studs.',
#   'chunk_id': '101'},
#  {'question': 'How does the Sawzall PX-1000 perform in terms of durability?',
#   'answer': 'The build quality is solid, and it has survived a few drops without any problems.',
#   'chunk_id': '101'},
#  {'question': 'How user-friendly is the Sawzall PX-1000?',
#   'answer': 'The Sawzall PX-1000 is easy to use right out of the box, with straightforward instructions.',
#   'chunk_id': '102'},
#  {'question': 'What features contribute to the effectiveness of the Sawzall PX-1000 in locating studs?',
#   'answer': 'The Sawzall PX-1000 has a bright LED display and audible alerts, which help in quickly and accurately finding both wood and metal studs.',
#   'chunk_id': '102'},
#  {'question': 'How does the LED display of the Sawzall PX-1000 enhance its usability?',
#   'answer': 'The LED display shows real-time updates, making it easy to trace the outline of studs.',
#   'chunk_id': '103'},
#  {'question': 'What feature of the Sawzall PX-1000 helps in detecting obstacles behind walls?',
#   'answer': 'It can detect metal pipes behind the walls, preventing potential issues during installation.',
#   'chunk_id': '103'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for versatile cutting options?',
#   'answer': 'The adjustable speed dial allows for versatile cutting between wood, metal, and plastic.',
#   'chunk_id': '104'},
#  {'question': 'What benefit does the tool-less blade change system provide?',
#   'answer': 'The tool-less blade change system saves time, making blade swaps quick and easy.',
#   'chunk_id': '104'},
#  {'question': 'What features contribute to the precision of the Sawzall PX-1000?',
#   'answer': 'The adjustable speed dial provides excellent control over different materials, contributing to its unmatched precision.',
#   'chunk_id': '105'},
#  {'question': 'What advantage does the Sawzall PX-1000 offer regarding blade changes?',
#   'answer': 'The Sawzall PX-1000 allows for tool-free blade changes, saving time on the job.',
#   'chunk_id': '105'},
#  {'question': 'What feature allows for quick blade changes in the Sawzall PX-1000?',
#   'answer': 'The tool-less blade change system allows for quick blade changes.',
#   'chunk_id': '106'},
#  {'question': 'How does the adjustable speed setting benefit the Sawzall PX-1000?',
#   'answer': 'The adjustable speed settings provide great versatility for cutting different materials.',
#   'chunk_id': '106'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for easy use with various materials?',
#   'answer': 'The adjustable speed dial provides plenty of control for different materials.',
#   'chunk_id': '107'},
#  {'question': 'What design aspect of the Sawzall PX-1000 enhances its usability for intricate tasks?',
#   'answer': 'The compact design is perfect for intricate cuts.',
#   'chunk_id': '107'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for precise cuts?',
#   'answer': 'The adjustable speed dial allows for precise cuts in a variety of materials.',
#   'chunk_id': '108'},
#  {'question': 'What design aspect of the Sawzall PX-1000 enhances user convenience during blade changes?',
#   'answer': 'The tool-less blade change system is user-friendly and efficient.',
#   'chunk_id': '108'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for clean and precise cuts in different types of wood?',
#   'answer': 'The adjustable speed control is useful for getting clean, precise cuts in both hard and soft woods.',
#   'chunk_id': '109'},
#  {'question': 'What system does the Sawzall PX-1000 use for changing blades?',
#   'answer': 'The tool-less system allows for easy changing of blades, particularly when transitioning between different types of cuts.',
#   'chunk_id': '109'},
#  {'question': 'What feature of the Sawzall PX-1000 provides exceptional control over cutting speed?',
#   'answer': 'The adjustable speed dial provides exceptional control over cutting speed.',
#   'chunk_id': '110'},
#  {'question': 'What is a notable convenience feature of the Sawzall PX-1000 that makes maintaining the tool easier?',
#   'answer': 'The tool-less blade change system makes maintaining the tool easier.',
#   'chunk_id': '110'},
#  {'question': 'What feature of the Sawzall PX-1000 allows users to customize cutting speed?',
#   'answer': 'The adjustable speed dial allows users to tailor the cutting speed to the material at hand.',
#   'chunk_id': '111'},
#  {'question': 'What system does the Sawzall PX-1000 utilize for changing blades?',
#   'answer': 'The tool-less blade change system is straightforward and very efficient.',
#   'chunk_id': '111'},
#  {'question': 'How does the adjustable nozzle of the Sawzall PX-1000 enhance its performance?',
#   'answer': 'The adjustable nozzle settings allow for easy switching between broad coverage and fine detail.',
#   'chunk_id': '112'},
#  {'question': 'What kind of finish does the Sawzall PX-1000 provide?',
#   'answer': 'It provides a smooth and even finish with no streaks or drips.',
#   'chunk_id': '112'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for customization during use?',
#   'answer': 'The adjustable nozzle allows for customization of the spray pattern.',
#   'chunk_id': '113'},
#  {'question': 'How easy is the cleanup process for the Sawzall PX-1000?',
#   'answer': 'The cleanup is straightforward, and the sprayer disassembles easily for thorough washing.',
#   'chunk_id': '113'},
#  {'question': 'What advantage does the Sawzall PX-1000 offer for lengthy projects?',
#   'answer': 'The Sawzall PX-1000 is powerful yet lightweight, preventing fatigue even after hours of use.',
#   'chunk_id': '114'},
# ...
#   'answer': 'The ergonomic handle design makes it comfortable to use for extended periods without causing hand fatigue.',
#   'chunk_id': '345'},
#  {'question': 'How does the adjustment knob function on the Sawzall PX-1000?',
#   'answer': 'The adjustment knob is smooth and allows for quick changes to accommodate different pipe sizes.',
#   'chunk_id': '346'},
#  {'question': 'What types of materials can the Sawzall PX-1000 cut through?',
#   'answer': 'It cuts through materials like PVC, CPVC, and copper effortlessly.',
#   'chunk_id': '346'},
#  {'question': 'What type of pipes can the Sawzall PX-1000 cut?',
#   'answer': 'The Sawzall PX-1000 can cut both metal and plastic pipes.',
#   'chunk_id': '347'},
#  {'question': 'How does the Sawzall PX-1000 perform in terms of cutting?',
#   'answer': 'The Sawzall PX-1000 delivers smooth cuts and has an incredibly sharp blade.',
#   'chunk_id': '347'},
#  {'question': 'How effective is the Sawzall PX-1000 in tight spaces?',
#   'answer': 'The Sawzall PX-1000 is fantastic for tight spaces due to its compact size.',
#   'chunk_id': '348'},
#  {'question': 'How does the adjustment knob perform on the Sawzall PX-1000?',
#   'answer': 'The adjustment knob turns effortlessly, and there has been no slippage during adjustments.',
#   'chunk_id': '348'},
#  {'question': 'What is a notable feature of the Sawzall PX-1000 regarding its cutting performance?',
#   'answer': 'The blade maintains its sharpness longer than others, allowing for precision cutting.',
#   'chunk_id': '349'},
#  {'question': 'How does the Sawzall PX-1000 handle different sizes of pipes?',
#   'answer': 'It handles both large and small diameter pipes with ease.',
#   'chunk_id': '349'},
#  {'question': 'What types of pipes can the Sawzall PX-1000 cut through?',
#   'answer': 'The Sawzall PX-1000 can cut cleanly through copper, PVC, and tough stainless steel pipes.',
#   'chunk_id': '350'},
#  {'question': 'What feature makes it easy to adjust the size of the Sawzall PX-1000?',
#   'answer': 'The adjustment knob is clearly marked, making it easy to set the correct size.',
#   'chunk_id': '350'},
#  {'question': 'What types of materials can the Sawzall PX-1000 cut?',
#   'answer': 'The Sawzall PX-1000 can cut PVC, CPVC, and copper.',
#   'chunk_id': '351'},
#  {'question': 'What feature of the Sawzall PX-1000 contributes to making quick adjustments?',
#   'answer': 'The adjustment knob is user-friendly and allows for quick adjustments.',
#   'chunk_id': '351'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for precision in detailed work?',
#   'answer': 'The adjustable bevel angle is incredibly precise, making it perfect for detailed work.',
#   'chunk_id': '352'},
#  {'question': 'How does the Sawzall PX-1000 perform in terms of cutting through materials?',
#   'answer': 'It cuts through hardwood like butter.',
#   'chunk_id': '352'},
#  {'question': 'What feature of the Sawzall PX-1000 ensures accuracy during cuts?',
#   'answer': 'The laser guide ensures pinpoint accuracy every time.',
#   'chunk_id': '353'},
#  {'question': 'What aspect of the Sawzall PX-1000 contributes to its ease of transportation?',
#   'answer': 'The tool is both sturdy and lightweight, making it ideal for transporting between job sites.',
#   'chunk_id': '353'},
#  {'question': 'What feature of the Sawzall PX-1000 aids in making accurate cuts?',
#   'answer': 'The saw comes with an easy-to-read scale, which helps in making accurate measurements.',
#   'chunk_id': '354'},
#  {'question': 'What ergonomic feature does the Sawzall PX-1000 have to reduce user fatigue?',
#   'answer': 'The handle design is ergonomic, reducing hand fatigue during prolonged use.',
#   'chunk_id': '354'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for complicated cuts without repositioning the workpiece?',
#   'answer': 'The dual bevel feature allows for complicated cuts without having to reposition the workpiece.',
#   'chunk_id': '355'},
#  {'question': 'How does the Sawzall PX-1000 perform in terms of dust collection?',
#   'answer': 'The included dust bag works fairly well, but connecting it to a shop vac significantly improves dust collection.',
#   'chunk_id': '355'},
#  {'question': 'What feature of the Sawzall PX-1000 enhances the range of cuts?',
#   'answer': 'The sliding function provides a greater range of cuts.',
#   'chunk_id': '356'},
#  {'question': 'What aspect of the Sawzall PX-1000 contributes to its precision and safety?',
#   'answer': 'The included clamp helps secure the material firmly, adding to precision and safety.',
#   'chunk_id': '356'},
#  {'question': 'What is a notable feature of the Sawzall PX-1000 that enhances safety?',
#   'answer': 'The electric brake, which quickly stops the blade, adds an extra layer of safety.',
#   'chunk_id': '357'},
#  {'question': 'How does the design of the Sawzall PX-1000 contribute to its usability?',
#   'answer': 'Its compact design and lightweight build make it very portable, ideal for both home and professional use.',
#   'chunk_id': '357'},
#  {'question': 'What features of the Sawzall PX-1000 contribute to its safety?',
#   'answer': 'The Sawzall PX-1000 has robust safety features, including a blade guard and electric brake.',
#   'chunk_id': '358'},
#  {'question': 'How does the Sawzall PX-1000 perform in terms of noise level?',
#   'answer': 'The Sawzall PX-1000 is surprisingly quiet, making it suitable for a home workshop.',
#   'chunk_id': '358'},
#  {'question': "What features contribute to the Sawzall PX-1000's performance?",
#   'answer': "The adjustable bevel angle, laser guide, and portability with a built-in carrying handle contribute to the Sawzall PX-1000's performance.",
#   'chunk_id': '359'},
#  {'question': 'How does the Sawzall PX-1000 handle different types of wood?',
#   'answer': 'The Sawzall PX-1000 performs flawlessly when cutting various types of wood, from pine to oak.',
#   'chunk_id': '359'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for precise soldering of delicate components?',
#   'answer': 'The adjustable temperature control allows for incredibly precise soldering of delicate components.',
#   'chunk_id': '360'},
#  {'question': 'How quickly does the Sawzall PX-1000 reach the desired temperature?',
#   'answer': 'The Sawzall PX-1000 heats up quickly, reaching the desired temperature in less than a minute.',
#   'chunk_id': '360'},
#  {'question': 'What feature of the Sawzall PX-1000 allows versatility in working with different solder types?',
#   'answer': 'The temperature adjustment feature allows versatility in working with different types of solder.',
#   'chunk_id': '361'},
#  {'question': 'How does the design of the Sawzall PX-1000 contribute to user safety?',
#   'answer': 'The included stand keeps the hot iron safely away from the workspace, contributing to user safety.',
#   'chunk_id': '361'},
#  {'question': 'What feature of the Sawzall PX-1000 contributes to its efficient performance during electrical repairs?',
#   'answer': 'The quick heat-up time is a huge plus, and the iron maintains a consistent temperature throughout use.',
#   'chunk_id': '362'},
#  {'question': 'How does the tip of the Sawzall PX-1000 affect the quality of solder joints?',
#   'answer': 'The tip is durable and provides excellent heat transfer, making solder joints clean and strong.',
#   'chunk_id': '362'},
#  {'question': 'What is the range of adjustable temperature settings for the Sawzall PX-1000?',
#   'answer': 'The adjustable temperature settings range from 200°C to 450°C.',
#   'chunk_id': '363'},
#  {'question': 'How does the Sawzall PX-1000 perform at high temperature settings?',
#   'answer': 'Even on the highest settings, the iron remains stable without overheating.',
#   'chunk_id': '363'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for precise temperature control?',
#   'answer': 'The Sawzall PX-1000 has an adjustable temperature control that is very responsive.',
#   'chunk_id': '364'},
#  {'question': 'How does the Sawzall PX-1000 assist in maintaining the cleanliness of its tips?',
#   'answer': 'The Sawzall PX-1000 comes with an included cleaning sponge that is effective in keeping the tips clean during use.',
#   'chunk_id': '364'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for precise control during use?',
#   'answer': 'The adjustable temperature feature allows for precise control, making it easier to work on sensitive electronic components.',
#   'chunk_id': '365'},
#  {'question': 'How does the Sawzall PX-1000 perform in terms of heating and cooling?',
#   'answer': 'The iron heats up fast and cools down quickly, minimizing downtime between projects.',
#   'chunk_id': '365'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for versatility in various projects?',
#   'answer': 'The adjustable temperature control covers a wide range.',
#   'chunk_id': '366'},
#  {'question': 'How quickly does the Sawzall PX-1000 heat up?',
#   'answer': "It heats up quickly and doesn't lose temperature even during extended use.",
#   'chunk_id': '366'},
#  {'question': 'What temperature feature does the Sawzall PX-1000 provide?',
#   'answer': 'The Sawzall PX-1000 allows for adjustable temperature.',
#   'chunk_id': '367'},
#  {'question': 'What is a notable ergonomic feature of the Sawzall PX-1000?',
#   'answer': 'The Sawzall PX-1000 has a rubberized handle that provides a comfortable grip, reducing hand fatigue.',
#   'chunk_id': '367'},
#  {'question': 'What is the range of temperature control for the Sawzall PX-1000?',
#   'answer': 'The variable temperature control ranges from 120°F to 1200°F.',
#   'chunk_id': '368'},
#  {'question': 'What features contribute to the ease of use for the Sawzall PX-1000?',
#   'answer': 'The ergonomic handle and the integrated stand contribute to ease of use, allowing for comfortable handling and hands-free operation.',
#   'chunk_id': '368'},
#  {'question': 'What feature of the Sawzall PX-1000 enhances usability during operation?',
#   'answer': 'The Sawzall PX-1000 has a digital display that shows the current temperature setting, enhancing usability.',
#   'chunk_id': '369'},
#  {'question': 'How does the weight of the Sawzall PX-1000 compare to other models, and what is the impact of this?',
#   'answer': 'The Sawzall PX-1000 is slightly heavier than other models, but the increase in performance is considered worth the extra weight.',
#   'chunk_id': '369'},
#  {'question': 'What feature of the Sawzall PX-1000 helps prevent damage during intensive use?',
#   'answer': 'It has an overheat protection system.',
#   'chunk_id': '370'},
#  {'question': 'How long is the power cord of the Sawzall PX-1000?',
#   'answer': 'The power cord is about 6 feet long.',
#   'chunk_id': '370'},
#  {'question': 'What feature of the Sawzall PX-1000 enhances safety during use?',
#   'answer': 'The cool-down mode allows the gun to gradually reduce in temperature, enhancing safety.',
#   'chunk_id': '371'},
#  {'question': 'What aspect of the Sawzall PX-1000 contributes to its versatility?',
#   'answer': 'The range of nozzle attachments included is impressive and adds to its versatility.',
#   'chunk_id': '371'},
#  {'question': 'What material is the Sawzall PX-1000 effective for bending?',
#   'answer': 'The Sawzall PX-1000 is effective for bending PVC pipes.',
#   'chunk_id': '372'},
#  {'question': 'What feature of the Sawzall PX-1000 enhances its usability with different materials?',
#   'answer': "The variable speed control enhances the Sawzall PX-1000's usability with different materials.",
#   'chunk_id': '372'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for quick temperature adjustments?',
#   'answer': 'The dual-temperature settings allow for quick and easy switching between low and high heat.',
#   'chunk_id': '373'},
#  {'question': 'What safety feature is included in the Sawzall PX-1000?',
#   'answer': 'The product has a built-in thermal cut-out, providing an extra layer of safety.',
#   'chunk_id': '373'},
#  {'question': 'What feature of the Sawzall PX-1000 allows for precise heating during use?',
#   'answer': "The precision nozzle allows for focused heat application exactly where it's needed without affecting surrounding areas.",
#   'chunk_id': '374'},
#  {'question': 'How does the Sawzall PX-1000 compare to other models in terms of noise level?',
#   'answer': 'The noise level of the Sawzall PX-1000 is quite low compared to other models.',
#   'chunk_id': '374'},
#  {'question': 'How adjustable is the temperature of the Sawzall PX-1000?',
#   'answer': 'The temperature can be adjusted in 50-degree increments, offering excellent control.',
#   'chunk_id': '375'},
#  {'question': "What is a notable feature of the Sawzall PX-1000's design?",
#   'answer': 'It is lightweight yet durable, and has a rubberized grip for added comfort during use.',
#   'chunk_id': '375'},
#  {'question': 'What type of cutting does the Sawzall PX-1000 enable due to its tooth configurations?',
#   'answer': 'The different tooth configurations allow for seamless switching between cutting hardwood and softwood.',
#   'chunk_id': '376'},
#  {'question': 'How do the blades of the Sawzall PX-1000 perform over time regarding sharpness?',
#   'answer': 'The blades show no signs of dulling after six months of use.',
#   'chunk_id': '376'},
#  {'question': 'What type of materials can the Sawzall PX-1000 cut through?',
#   'answer': 'The Sawzall PX-1000 can cut through materials such as aluminum and plastic.',
#   'chunk_id': '377'},
#  {'question': 'What is a notable feature of the 60-tooth blade included in the Sawzall PX-1000 set?',
#   'answer': 'The 60-tooth blade excels at providing smooth, splinter-free cuts in plywood.',
#   'chunk_id': '377'},
#  {'question': 'What characteristic of the Sawzall PX-1000 contributes to its long-lasting performance?',
#   'answer': 'The durability of the carbide-tipped teeth ensures that more cuts can be made per blade, reducing the need for frequent replacements.',
#   'chunk_id': '378'},
#  {'question': 'How does the Sawzall PX-1000 accommodate different cutting needs?',
#   'answer': 'The variety of tooth configurations allows for handling a wide range of materials without the need to switch tools constantly.',
#   'chunk_id': '378'},
#  {'question': 'How does the 24-tooth blade perform for rough framing work?',
#   'answer': 'The 24-tooth blade works wonderfully for rough framing work, making quick and aggressive cuts.',
#   'chunk_id': '379'},
#  {'question': 'What are the benefits of the blades in terms of user experience?',
#   'answer': 'The blades are well-balanced and minimize vibration, which helps in reducing user fatigue.',
#   'chunk_id': '379'},
#  {'question': 'How well do the Sawzall PX-1000 blades cut through wood?',
#   'answer': 'They cut through 2x4 lumber like butter, even on the lower power setting.',
#   'chunk_id': '380'},
#  {'question': 'What feature helps the Sawzall PX-1000 blades stay sharper longer?',
#   'answer': 'The blades are coated to reduce friction, which helps with heat buildup and keeps them sharper longer.',
#   'chunk_id': '380'},
#  {'question': 'What is a notable feature of the blade design for the Sawzall PX-1000?',
#   'answer': 'The thin kerf design helps in maximizing cutting efficiency while using less power.',
#   'chunk_id': '381'},
#  {'question': 'How do the blades perform after multiple uses?',
#   'answer': 'After making dozens of cuts, the blades still look and perform like new.',
#   'chunk_id': '381'},
#  {'question': 'What feature of the saw blades enhances cutting through laminate flooring?',
#   'answer': 'The triple chip grind teeth enhance cutting through laminate flooring with no chipping.',
#   'chunk_id': '382'},
#  {'question': 'What benefit do the expansion slots in the blade provide?',
#   'answer': 'The expansion slots help in reducing noise and vibration.',
#   'chunk_id': '382'},
#  {'question': 'What type of cuts do the fine-tooth blades produce?',
#   'answer': 'The fine-tooth blades produce extremely smooth cuts.',
#   'chunk_id': '383'},
#  {'question': 'What safety feature does the Sawzall PX-1000 include?',
#   'answer': 'The Sawzall PX-1000 includes an anti-kickback design for added safety.',
#   'chunk_id': '383'}]

# %% [markdown]
# ## Set Up Evaluatoin
#
# Load the evaluation questions into a structured format.

# %%
from pydantic import BaseModel


class EvalQuestion(BaseModel):
    question: str
    answer: str
    chunk_id: str


eval_questions = [EvalQuestion(**question) for question in synthetic_questions]

# %% [markdown]
# Build a simple search function

# %%
def run_simple_request(q: EvalQuestion, n_return_vals=5):
    results = reviews_table.search(q.question).limit(n_return_vals).to_list()
    returned_ids = [r["id"] for r in results]
    return [str(q.chunk_id) == r for r in returned_ids]

# %% [markdown]
# Now do the benchmarking. For simplicity, we will just compare retrieval sizes for now.

# %%
def score(hits):
    # This implementation assumes
    n_retrieval_requests = len(hits)
    total_retrievals = sum([len(l) for l in hits])
    true_positives = sum([sum(sublist) for sublist in hits])
    precision = true_positives / total_retrievals
    recall = true_positives / n_retrieval_requests
    return {"precision": precision, "recall": recall}


def score_simple_search(n_to_retrieve: List[int]) -> Dict[str, float]:
    in_raw_dataset = [run_simple_request(i, n_to_retrieve) for i in eval_questions]
    return score(in_raw_dataset)


k_to_retrieve = [5, 10, 20]
scores = pd.DataFrame([score_simple_search(n) for n in k_to_retrieve])
scores["n_retrieved"] = k_to_retrieve
scores
# Out:
#    precision    recall  n_retrieved
# 0   0.051429  0.257143            5
# 1   0.034805  0.348052           10
# 2   0.021494  0.429870           20
