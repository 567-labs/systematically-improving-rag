# %% [markdown]
# # Context
#
# In `make_synthetic_questions.ipynb`, we generated synthetic questions to bootstrap evaluation of the retrieval system in our hardware store's Q&A system.
#
# This notebook shows the first step in calculating precision and recall with different retrieval parameters. We will run more advanced experiments in future notebooks after we have these baseline scores.
#
# ## Data
#
# Here is a brief review of the data.

# %%
import json
import lancedb
import os
import pandas as pd
from typing import List, Dict
from concurrent.futures import ThreadPoolExecutor

pd.set_option("display.max_colwidth", 160)

db = lancedb.connect("./lancedb")
reviews_table = db.open_table("reviews")
reviews_table.to_pandas().head()
# Out:
#   id   product_title  \
# 0  0  Cordless Drill
# 1  1  Cordless Drill
# 2  2  Cordless Drill
# 3  3  Cordless Drill
# 4  4  Cordless Drill
#
#                                                                                                                                                product_description  \
# 0  This powerful cordless drill features a lightweight design and a 2-speed transmission, allowing you to tackle various tasks with ease. Ideal for both profes...
# 1  This powerful cordless drill features a lightweight design and a 2-speed transmission, allowing you to tackle various tasks with ease. Ideal for both profes...
# 2  This powerful cordless drill features a lightweight design and a 2-speed transmission, allowing you to tackle various tasks with ease. Ideal for both profes...
# 3  This powerful cordless drill features a lightweight design and a 2-speed transmission, allowing you to tackle various tasks with ease. Ideal for both profes...
# 4  This powerful cordless drill features a lightweight design and a 2-speed transmission, allowing you to tackle various tasks with ease. Ideal for both profes...
#
#                                                                                                                                                             review  \
# 0  I've owned several cordless drills over the years, but this one is exceptional. It is lightweight, making it easy to use for extended periods without fatigu...
# 1  As a professional contractor, I rely on my tools every day. This cordless drill has exceeded my expectations with its powerful motor and ergonomic design. T...
# 2  I'm a DIY enthusiast and bought this cordless drill for home projects. It's perfect for everything from hanging shelves to assembling furniture. The drill i...
# 3  After using this cordless drill for several months, I can confidently say it's one of the best I've owned. The lightweight design makes it comfortable to us...
# 4  This cordless drill has become my go-to tool for all my DIY projects. The lightweight design reduces strain on my wrist, and the 2-speed transmission is inc...
#
#                                                                                                                                                             vector
# 0  [0.012451614, 0.009677136, -0.013976053, -0.02875701, 0.017634707, 0.0003763458, -0.01216502, 0.0825392, 0.03673287, -0.021500682, 0.023537332, 0.03043999, ...
# 1  [0.028722303, -0.00047558517, -0.0009903691, -0.019788183, 0.018789813, 0.0009975688, -0.035096504, 0.07188256, 0.015909903, -0.010137284, 0.028875899, -0.0...
# 2  [-0.011681931, 0.0018038707, -0.02288322, -0.030081118, 0.042812254, 0.0008550435, -0.035051655, 0.07488628, 0.0060666325, 0.0003996797, 0.019682853, 0.0155...
# 3  [0.018682713, 0.02133356, -0.0092318645, -0.031441357, 0.02241695, 0.0017821187, 0.0009205933, 0.06265221, 0.05357017, 0.0011827967, 0.046009492, 0.00949118...
# 4  [0.016187381, 0.004412105, -0.019909551, -0.01881957, 0.019747214, -0.013334877, -0.027829308, 0.060018543, 0.0031047072, -0.008151668, 0.006702225, 0.02581...

# %%
with open("synthetic_eval_dataset.json", "r") as f:
    synthetic_questions = json.load(f)
synthetic_questions
# Out:
# [{'question': 'How good is the battery life on this cordless drill?',
#   'answer': 'It comes with two included batteries, ensuring that you never run out of power on the job.',
#   'chunk_id': '0'},
#  {'question': 'Is this cordless drill easy to handle for long tasks?',
#   'answer': 'Yes, its lightweight design makes it easy to use for extended periods without fatigue.',
#   'chunk_id': '0'},
#  {'question': 'How powerful is the motor in this cordless drill?',
#   'answer': 'The cordless drill features a powerful motor that exceeds expectations for professional use.',
#   'chunk_id': '1'},
#  {'question': 'What design features make this drill suitable for overhead tasks?',
#   'answer': 'The cordless drill has a lightweight design and ergonomic build, making it perfect for overhead tasks.',
#   'chunk_id': '1'},
#  {'question': 'How durable are the batteries for this cordless drill?',
#   'answer': 'The batteries charge quickly and last a long time, which is a huge plus.',
#   'chunk_id': '2'},
#  {'question': "What's the weight like for this cordless drill when using it for projects?",
#   'answer': 'The drill is lightweight and easy to maneuver, making it suitable for various home projects.',
#   'chunk_id': '2'},
#  {'question': 'How lightweight is this cordless drill?',
#   'answer': 'The cordless drill features a lightweight design, making it comfortable to use.',
#   'chunk_id': '3'},
#  {'question': 'Can this drill handle tough materials?',
#   'answer': 'Yes, it can handle everything from drilling into concrete to driving long screws into wood without any issues.',
#   'chunk_id': '3'},
#  {'question': 'How is the weight of the cordless drill described?',
#   'answer': 'The cordless drill features a lightweight design that reduces strain on the wrist.',
#   'chunk_id': '4'},
#  {'question': 'What are the key features of this cordless drill?',
#   'answer': 'Key features include a 2-speed transmission for different tasks and an extra battery for extended usage.',
#   'chunk_id': '4'},
#  {'question': 'Is the cordless drill lightweight and easy to handle?',
#   'answer': 'Yes, the cordless drill features a lightweight design that makes it easy to use for extended periods.',
#   'chunk_id': '5'},
#  {'question': 'How well does the battery perform for the cordless drill?',
#   'answer': 'The batteries last a long time and charge quickly, which is crucial for heavy-duty tasks.',
#   'chunk_id': '5'},
#  {'question': 'Is this cordless drill good for different projects?',
#   'answer': 'Yes, this cordless drill is reliable for various projects, including building outdoor furniture and drilling into masonry.',
#   'chunk_id': '6'},
#  {'question': 'What features does this cordless drill have for handling and usage?',
#   'answer': 'It has a lightweight design and a 2-speed transmission, making it easy to handle and suitable for both drilling and driving.',
#   'chunk_id': '6'},
#  {'question': 'How light is this cordless drill and why does it matter?',
#   'answer': 'The cordless drill is lightweight, making it easy to use for extended periods.',
#   'chunk_id': '7'},
#  {'question': 'Does the drill have any special features for convenience?',
#   'answer': 'Yes, it has a 2-speed transmission and comes with an extra battery for extended use.',
#   'chunk_id': '7'},
#  {'question': 'How long do the batteries last on this cordless drill?',
#   'answer': 'The batteries last a long time and provide consistent power.',
#   'chunk_id': '8'},
#  {'question': "What's special about the drill's design or operation?",
#   'answer': 'It features a lightweight design for comfort during prolonged use and a 2-speed transmission for added functionality.',
#   'chunk_id': '8'},
#  {'question': 'How does the lightweight design of the cordless drill help during use?',
#   'answer': 'The lightweight design makes it easy to handle, especially during woodworking projects.',
#   'chunk_id': '9'},
#  {'question': 'What feature of the cordless drill aids in completing different tasks?',
#   'answer': 'The 2-speed transmission is perfect for various drilling and driving tasks.',
#   'chunk_id': '9'},
#  {'question': 'How many torque settings does this cordless drill have?',
#   'answer': 'It has 18 torque settings.',
#   'chunk_id': '10'},
#  {'question': 'Is the cordless drill good for working in tight spaces?',
#   'answer': 'Yes, its compact design is perfect for cramped spaces.',
#   'chunk_id': '10'},
#  {'question': 'How does the drill handle long projects without overheating?',
#   'answer': 'The drill can be used continuously without overheating, making it suitable for long projects.',
#   'chunk_id': '11'},
#  {'question': "What's a cool feature for using the drill in dim light?",
#   'answer': 'The drill has an LED light, which is great for working in low-light conditions.',
#   'chunk_id': '11'},
#  {'question': 'How does the cordless drill perform for DIY projects?',
#   'answer': 'It performs exceptionally well for DIY projects, being lightweight yet powerful enough to handle tougher materials.',
#   'chunk_id': '12'},
#  {'question': 'What features make this drill easy to use?',
#   'answer': 'The 18 torque settings allow for precise control, helping to avoid overdriving screws, and it has a quick-charge feature that fully charges in less than an hour.',
#   'chunk_id': '12'},
#  {'question': "How's the battery life on this cordless drill?",
#   'answer': "The battery lasts longer than expected and the drill's performance hasn't diminished over time.",
#   'chunk_id': '13'},
#  {'question': 'Is this cordless drill good for small projects?',
#   'answer': "Yes, it's ideal for small jobs like assembling furniture or drilling pilot holes for wall mounts.",
#   'chunk_id': '13'},
#  {'question': 'How comfortable is the grip of the cordless drill during use?',
#   'answer': 'The ergonomic grip of the cordless drill ensures comfort during prolonged use, reducing fatigue.',
#   'chunk_id': '14'},
#  {'question': 'What kind of tasks can I perform with this cordless drill?',
#   'answer': 'With 18 torque settings, the cordless drill is perfect for a variety of tasks and performs well in both high and low-speed settings.',
#   'chunk_id': '14'},
#  {'question': 'How many torque settings does this cordless drill have?',
#   'answer': 'This cordless drill offers 18 torque settings.',
#   'chunk_id': '15'},
#  {'question': 'Is this drill suitable for tight spaces?',
#   'answer': 'Yes, the compact design of the drill allows it to work effectively in tight spaces.',
#   'chunk_id': '15'},
#  {'question': 'How does the battery life of this cordless drill hold up?',
#   'answer': 'The battery life is outstanding and it recharges relatively quickly.',
#   'chunk_id': '16'},
#  {'question': 'Is the grip on this cordless drill comfortable for extended use?',
#   'answer': 'Yes, the ergonomic grip is comfortable for prolonged use.',
#   'chunk_id': '16'},
#  {'question': 'How many torque settings does this cordless drill have?',
#   'answer': 'The cordless drill has 18 torque settings.',
#   'chunk_id': '17'},
#  {'question': 'Is the cordless drill easy to store?',
#   'answer': 'Yes, the compact design makes it easy to store in a toolbox.',
#   'chunk_id': '17'},
#  {'question': 'How easy is it to switch drill bits with this cordless drill?',
#   'answer': 'The quick-change chuck makes switching between drill bits seamless.',
#   'chunk_id': '18'},
#  {'question': 'Does this cordless drill have a comfortable grip for long use?',
#   'answer': "Yes, the ergonomic grip ensures that the hand doesn't get tired, even after hours of use.",
#   'chunk_id': '18'},
#  {'question': 'How many torque settings does this cordless drill have?',
#   'answer': 'This cordless drill offers 18 torque settings, allowing for adjustments in power output depending on the task.',
#   'chunk_id': '19'},
#  {'question': 'Can this drill work in tight spaces?',
#   'answer': "Yes, the drill's compact design makes it perfect for use in tight spots without any issues.",
#   'chunk_id': '19'},
#  {'question': 'How does the cordless drill perform on different materials?',
#   'answer': 'It has a high-performance motor that effortlessly drills through both wood and metal.',
#   'chunk_id': '20'},
#  {'question': 'What feature helps with visibility in dark areas during use?',
#   'answer': "The LED light illuminates dark corners where natural light can't reach.",
#   'chunk_id': '20'},
#  {'question': 'How good is the battery life on this cordless drill?',
#   'answer': 'The battery life is impressive, with the user having charged it only a handful of times since purchase.',
#   'chunk_id': '21'},
#  {'question': 'Is the LED light feature useful for this cordless drill?',
#   'answer': 'Yes, the LED light is very useful as it illuminates dark work areas, making it easier to work in poorly lit conditions.',
#   'chunk_id': '21'},
#  {'question': "How's the battery life on this cordless drill?",
#   'answer': 'The battery life is excellent, suitable for long hours of work.',
#   'chunk_id': '22'},
#  {'question': 'What features help with visibility when using the drill?',
#   'answer': 'The LED light is bright and strategically placed, providing excellent visibility in dark spaces.',
#   'chunk_id': '22'},
#  {'question': 'How powerful is the motor on this cordless drill?',
#   'answer': 'The motor is quite powerful and tackles heavy-duty jobs with ease.',
#   'chunk_id': '23'},
#  {'question': 'What features make this drill suitable for low-light conditions?',
#   'answer': 'The LED light is a useful feature, especially when working in areas with poor lighting.',
#   'chunk_id': '23'},
#  {'question': 'How powerful is the motor in this cordless drill?',
#   'answer': 'The motor delivers a lot of power, making it easy to drill through various materials.',
#   'chunk_id': '24'},
#  {'question': 'Does this cordless drill have a light for dark areas?',
#   'answer': 'Yes, it has a built-in LED light that is super helpful when working in dark areas like inside cabinets or under sinks.',
#   'chunk_id': '24'},
#  {'question': 'How well does this cordless drill handle tough materials?',
#   'answer': 'This cordless drill performs exceptionally well with tough materials like stone and brick due to its high-performance motor.',
#   'chunk_id': '25'},
#  {'question': 'What features make this drill suitable for evening use?',
#   'answer': 'The bright LED light is a great feature that comes in handy during late evening work sessions, illuminating dark work areas.',
#   'chunk_id': '25'},
#  {'question': 'How powerful is the motor on this cordless drill?',
#   'answer': 'The motor is incredibly powerful, allowing for efficient drilling and driving, which helps complete projects quickly.',
#   'chunk_id': '26'},
#  {'question': 'Does this cordless drill have any special features for visibility?',
#   'answer': 'Yes, it has an LED light that provides ample illumination in dark areas, perfect for indoor and outdoor tasks.',
#   'chunk_id': '26'},
#  {'question': 'How good is the battery life on this cordless drill?',
#   'answer': 'The battery life is impressive; it lasts through multiple projects on a single charge.',
#   'chunk_id': '27'},
#  {'question': 'Is this cordless drill suitable for use in dark areas?',
#   'answer': 'Yes, the LED light is bright and helps a lot in dimly lit areas.',
#   'chunk_id': '27'},
#  {'question': 'How well does the battery perform in this cordless drill?',
#   'answer': 'The battery lasts amazingly long, allowing users to get through days of work without needing to recharge.',
#   'chunk_id': '28'},
#  {'question': 'Is this cordless drill good for working in dark areas?',
#   'answer': 'Yes, it has an LED light that illuminates areas where lighting is poor, making it suitable for dark work conditions.',
#   'chunk_id': '28'},
#  {'question': 'How well does the battery perform on this cordless drill?',
#   'answer': 'The battery holds its charge very well and lasts for multiple projects.',
#   'chunk_id': '29'},
#  {'question': 'Does this cordless drill work well in low light conditions?',
#   'answer': 'Yes, the LED light is very handy for working in low light conditions.',
#   'chunk_id': '29'},
#  {'question': 'How does the cushioned grip of the adjustable wrench feel during long use?',
#   'answer': 'The cushioned grip feels great even after prolonged use.',
#   'chunk_id': '30'},
#  {'question': 'Is the adjustable wrench lightweight and durable at the same time?',
#   'answer': 'Yes, it’s surprisingly lightweight without sacrificing durability.',
#   'chunk_id': '30'},
#  {'question': 'How comfortable is the grip on this adjustable wrench?',
#   'answer': 'The adjustable wrench features a cushioned grip that offers both comfort and control during use.',
#   'chunk_id': '31'},
#  {'question': 'Is the jaw opening of the wrench suitable for different tasks?',
#   'answer': 'Yes, the wide jaw opening accommodates various fastener sizes, making it perfect for a variety of tasks.',
#   'chunk_id': '31'},
#  {'question': "How's the grip on this adjustable wrench?",
#   'answer': 'The grip is comfortable even during long sessions.',
#   'chunk_id': '32'},
#  {'question': 'Is this wrench durable enough for tough jobs?',
#   'answer': 'The build quality is excellent and has survived numerous drops without any issues.',
#   'chunk_id': '32'},
#  {'question': 'How comfortable is the grip on the adjustable wrench?',
#   'answer': 'The adjustable wrench features a cushioned grip that is very ergonomic, reducing hand strain during use.',
#   'chunk_id': '33'},
#  {'question': 'Is it easy to adjust the jaw width on this wrench?',
#   'answer': 'Yes, adjusting the jaw width is quick and easy, and it stays locked in place while working.',
#   'chunk_id': '33'},
#  {'question': 'How comfy is the grip on this adjustable wrench?',
#   'answer': 'The adjustable wrench has a cushioned grip that is incredibly comfortable.',
#   'chunk_id': '34'},
#  {'question': 'Does this wrench take up a lot of space in my toolbag?',
#   'answer': 'No, the sleek design means it doesn’t take up much space in the toolbag.',
#   'chunk_id': '34'},
#  {'question': 'How does the adjustable wrench feel in terms of grip during use?',
#   'answer': 'The adjustable wrench has a cushioned grip that provides excellent comfort and control.',
#   'chunk_id': '35'},
#  {'question': 'Is the adjustable wrench durable enough for heavy tasks?',
#   'answer': 'Yes, it feels sturdy and well-built, able to withstand heavy use without any signs of wear and tear.',
#   'chunk_id': '35'},
#  {'question': 'How comfy is the grip on this adjustable wrench?',
#   'answer': 'The cushioned grip provides superb comfort, making long projects much easier on the hands.',
#   'chunk_id': '36'},
#  {'question': 'Can this adjustable wrench fit different fastener sizes?',
#   'answer': 'Yes, the jaw opens wide enough to fit various fastener sizes.',
#   'chunk_id': '36'},
#  {'question': 'Is the adjustable wrench easy to carry around?',
#   'answer': 'Yes, the adjustable wrench has a lightweight construction that makes it easy to store and carry around.',
#   'chunk_id': '37'},
#  {'question': "How's the grip on the adjustable wrench?",
#   'answer': 'The adjustable wrench features a cushioned grip that provides excellent comfort during extended use.',
#   'chunk_id': '37'},
#  {'question': 'How comfy is the grip on this adjustable wrench?',
#   'answer': 'The adjustable wrench features a cushioned grip that is very comfortable.',
#   'chunk_id': '38'},
#  {'question': 'Is this wrench sturdy and reliable for frequent use?',
#   'answer': 'The wrench is durable, feels solid in the hand, and the adjustment mechanism works flawlessly.',
#   'chunk_id': '38'},
#  {'question': 'How comfy is the grip on this adjustable wrench?',
#   'answer': 'The cushioned grip is extremely comfortable, even during prolonged use.',
#   'chunk_id': '39'},
#  {'question': 'Can this wrench handle larger fasteners?',
#   'answer': 'Yes, the jaw opens wide enough to handle all the different fasteners encountered.',
#   'chunk_id': '39'},
#  {'question': 'How durable is the adjustable wrench?',
#   'answer': 'The adjustable wrench is made from durable chrome vanadium steel, ensuring longevity and resistance to corrosion.',
#   'chunk_id': '40'},
#  {'question': 'Is the jaw scale easy to use for quick adjustments?',
#   'answer': 'Yes, the jaw scale is incredibly easy to read, making quick adjustments a breeze.',
#   'chunk_id': '40'},
#  {'question': 'What material is this adjustable wrench made of?',
#   'answer': 'The adjustable wrench is made from durable chrome vanadium steel.',
#   'chunk_id': '41'},
#  {'question': 'Does it have features that make size adjustments easy?',
#   'answer': 'Yes, it has an easy-to-read jaw scale that allows for quick adjustments.',
#   'chunk_id': '41'},
#  {'question': 'How tough is the adjustable wrench?',
#   'answer': 'Made from durable chrome vanadium steel, the adjustable wrench guarantees longevity and resistance to corrosion.',
#   'chunk_id': '42'},
#  {'question': 'Does the wrench help with efficiency?',
#   'answer': 'Yes, its easy-to-read jaw scale allows for quick adjustments, enhancing efficiency while working.',
#   'chunk_id': '42'},
#  {'question': 'How durable is this adjustable wrench?',
#   'answer': 'The adjustable wrench is made from chrome vanadium steel, which ensures longevity and resistance to corrosion.',
#   'chunk_id': '43'},
#  {'question': 'Is the jaw scale easy to read on this wrench?',
#   'answer': 'Yes, the jaw scale is clear and precise, allowing for quick adjustments.',
#   'chunk_id': '43'},
#  {'question': 'How durable is the adjustable wrench?',
#   'answer': 'The adjustable wrench is made from strong chrome vanadium steel, which guarantees longevity and resistance to wear and corrosion.',
#   'chunk_id': '44'},
#  {'question': 'Is it easy to adjust the size of this wrench?',
#   'answer': 'Yes, the adjustable wrench features an easy-to-read jaw scale that allows for quick and hassle-free size adjustments.',
#   'chunk_id': '44'},
#  {'question': 'How durable is the adjustable wrench?',
#   'answer': 'The adjustable wrench is made from chrome vanadium steel, which is extremely durable and resistant to corrosion.',
#   'chunk_id': '45'},
#  {'question': 'Is it easy to use in tight spaces?',
#   'answer': 'Yes, the jaw scale is very user-friendly, making it great for use in tight spaces.',
#   'chunk_id': '45'},
#  {'question': 'How durable is the adjustable wrench?',
#   'answer': "The adjustable wrench is made from durable chrome vanadium steel, which guarantees longevity and resistance to corrosion, ensuring it doesn't rust even after exposure to water.",
#   'chunk_id': '46'},
#  {'question': 'Is the jaw scale easy to use for adjustments?',
#   'answer': 'Yes, the jaw scale is easy to read and adjust, which enhances efficiency while working with the wrench.',
#   'chunk_id': '46'},
#  {'question': 'How durable is the adjustable wrench made from chrome vanadium steel?',
#   'answer': 'The adjustable wrench is very durable and made from chrome vanadium steel, which ensures it won’t rust easily.',
#   'chunk_id': '47'},
#  {'question': 'Does the wrench have any features for easy usage?',
#   'answer': 'Yes, it has an easy-to-read jaw scale that allows for quick adjustments, enhancing efficiency while working.',
#   'chunk_id': '47'},
#  {'question': 'How durable is the adjustable wrench?',
#   'answer': 'The adjustable wrench is made from durable chrome vanadium steel, ensuring longevity and resistance to corrosion.',
#   'chunk_id': '48'},
#  {'question': 'Is the jaw scale easy to read for adjustments?',
#   'answer': 'Yes, the jaw scale is very clear, making size adjustments easy and enhancing efficiency while working.',
#   'chunk_id': '48'},
#  {'question': 'Is this adjustable wrench really durable?',
#   'answer': 'Yes, it is made from chrome vanadium steel, making it incredibly durable and corrosion-resistant.',
#   'chunk_id': '49'},
#  {'question': 'How easy is it to make adjustments with this wrench?',
#   'answer': 'The jaw scale is easy to read, which saves time when making adjustments.',
#   'chunk_id': '49'},
#  {'question': 'How does this adjustable wrench handle tight spaces?',
#   'answer': "It's compact and fits easily into tight spaces, making it great for under-sink repairs.",
#   'chunk_id': '50'},
#  {'question': 'Is the adjustable mechanism of this wrench reliable over time?',
#   'answer': 'Yes, the adjustable mechanism is smooth and does not loosen over time like other wrenches.',
#   'chunk_id': '50'},
#  {'question': 'How does the adjustable wrench handle during use?',
#   'answer': 'The adjustable wrench is light enough for prolonged use without causing hand fatigue.',
#   'chunk_id': '51'},
#  {'question': 'What about the grip of the wrench?',
#   'answer': "The jaws have a powerful grip that doesn't let go, ensuring a tight hold on fasteners.",
#   'chunk_id': '51'},
#  {'question': 'How does the adjustable wrench feel in hand during use?',
#   'answer': 'It has a comfortable handle that provides excellent leverage.',
#   'chunk_id': '52'},
#  {'question': 'Can the jaws of this adjustable wrench handle different sizes of fasteners?',
#   'answer': 'Yes, the jaws adjust smoothly and grip onto various sizes of fasteners with ease.',
#   'chunk_id': '52'},
#  {'question': 'How does the adjustable wrench grip fasteners?',
#   'answer': 'The precision-engineered jaws ensure a tight grip on fasteners, reducing the risk of slipping.',
#   'chunk_id': '53'},
#  {'question': 'Is this adjustable wrench suitable for regular use?',
#   'answer': 'Yes, it has been used almost daily without any issues for six months, indicating its reliability and durability.',
#   'chunk_id': '53'},
#  {'question': 'How does the adjustable wrench perform under pressure?',
#   'answer': 'The adjustable jaw remains firmly in place under pressure, ensuring reliable performance.',
#   'chunk_id': '54'},
#  {'question': 'Is this adjustable wrench heavy or lightweight?',
#   'answer': 'The wrench is surprisingly lightweight, making it easier to handle compared to heavier models.',
#   'chunk_id': '54'},
#  {'question': 'How well does the adjustable wrench grip fasteners?',
#   'answer': 'The precision-engineered jaws ensure a tight grip, effectively reducing the chance of damaging fasteners.',
#   'chunk_id': '55'},
#  {'question': 'Is the adjustment mechanism smooth even after heavy use?',
#   'answer': 'Yes, the adjustment mechanism operates smoothly even after repeated use.',
#   'chunk_id': '55'},
#  {'question': 'How well does this adjustable wrench hold onto fasteners?',
#   'answer': 'The precision-engineered jaws ensure a tight grip on fasteners, reducing the risk of slipping.',
#   'chunk_id': '56'},
#  {'question': 'Is this wrench good for use in wet conditions?',
#   'answer': 'Yes, it is resistant to rust and corrosion, making it ideal for wet environments.',
#   'chunk_id': '56'},
#  {'question': 'How well does this adjustable wrench grip fasteners?',
#   'answer': 'The precision jaws grip fasteners perfectly, which is crucial for avoiding damage.',
#   'chunk_id': '57'},
#  {'question': 'Is the handle comfortable for long use?',
#   'answer': 'Yes, the ergonomic handle is comfortable to hold, even during extended use.',
#   'chunk_id': '57'},
#  {'question': 'How well do the jaws perform on this adjustable wrench?',
#   'answer': 'The jaws are finely engineered for a tight grip on fasteners, which reduces the risk of slipping.',
#   'chunk_id': '58'},
#  {'question': 'Is this adjustable wrench easy to maintain?',
#   'answer': 'Yes, it is easy to clean and maintain, and the adjustment mechanism has remained reliable over time.',
#   'chunk_id': '58'},
#  {'question': 'How does this adjustable wrench handle grip on fasteners?',
#   'answer': 'The precision-engineered jaws ensure a tight grip on fasteners, which reduces the risk of slipping.',
#   'chunk_id': '59'},
#  {'question': 'Is this wrench easy to adjust?',
#   'answer': 'Yes, the adjustment is both smooth and secure.',
#   'chunk_id': '59'},
#  {'question': 'How well does this heavy-duty extension cord hold up in bad weather?',
#   'answer': 'The heavy-duty extension cord is weather-resistant and has stayed outside through rain and snow without any issues.',
#   'chunk_id': '60'},
#  {'question': "What's the color of the heavy-duty extension cord and why is it important?",
#   'answer': 'The heavy-duty extension cord is bright orange, which is perfect for visibility and helps reduce the chance of tripping over it.',
#   'chunk_id': '60'},
#  {'question': 'How long is the heavy-duty extension cord and is that enough for outdoor use?',
#   'answer': 'The heavy-duty extension cord is 50 feet long, providing plenty of reach for outdoor projects without needing multiple cords.',
#   'chunk_id': '61'},
#  {'question': 'Is this extension cord tough enough for high-demand tools?',
#   'answer': 'Yes, this extension cord is sturdy and durable, and it powers high-demand tools like electric chainsaws and lawn mowers effectively.',
#   'chunk_id': '61'},
#  {'question': 'How flexible is the Heavy Duty Extension Cord in cold weather?',
#   'answer': "The Heavy Duty Extension Cord remains flexible even when it's cold outside, which is a common issue with other brands.",
#   'chunk_id': '62'},
#  {'question': 'What features make the connectors of this extension cord reliable?',
#   'answer': 'The extension cord has reinforced connectors that feel very secure, ensuring a steady electrical connection.',
#   'chunk_id': '62'},
#  {'question': 'How durable is the Heavy Duty Extension Cord compared to others?',
#   'answer': 'The Heavy Duty Extension Cord is built to last, with a strain relief design that prevents the plug from detaching, outperforming other extension cords.',
#   'chunk_id': '63'},
#  {'question': 'Can this extension cord handle heavy tools without issues?',
#   'answer': 'Yes, the Heavy Duty Extension Cord has a thick gauge that can handle heavy loads, like a welder, without overheating.',
#   'chunk_id': '63'},
#  {'question': 'How well does this extension cord perform under heavy loads?',
#   'answer': 'It handles the electrical load like a champ.',
#   'chunk_id': '64'},
#  {'question': "What’s a cool feature of this extension cord's design?",
#   'answer': 'The bright orange color makes it easy to spot and helps avoid damage.',
#   'chunk_id': '64'},
#  {'question': 'How thick is this heavy duty extension cord compared to standard ones?',
#   'answer': "It's thicker than most standard cords, providing better power flow and less drop in voltage over long distances.",
#   'chunk_id': '65'},
#  {'question': 'What features help this extension cord perform well in tough conditions?',
#   'answer': 'The molded plugs are robust, and the insulation has held up well against the rough conditions on various job sites.',
#   'chunk_id': '65'},
#  {'question': 'How does this extension cord handle heat when powering multiple lights?',
#   'answer': 'It never gets warm to the touch, even with all the lights on.',
#   'chunk_id': '66'},
#  {'question': 'Is the extension cord water-resistant?',
#   'answer': 'Yes, the water-resistant design has kept it functioning perfectly, even after heavy rains.',
#   'chunk_id': '66'},
#  {'question': 'How good is the reach of this heavy-duty extension cord?',
#   'answer': 'The cord has a great reach, making it suitable for outdoor use.',
#   'chunk_id': '67'},
#  {'question': 'Is this extension cord safe to use with heavy loads?',
#   'answer': 'Yes, it is designed to withstand heavy loads, reducing the worry about shorts or overloads.',
#   'chunk_id': '67'},
#  {'question': 'How tough is this heavy-duty extension cord?',
#   'answer': 'The extension cord is highly durable, showing no fraying or signs of wear even after being dragged around and occasionally driven over by a car.',
#   'chunk_id': '68'},
#  {'question': 'Does the extension cord hold up well after outdoor use?',
#   'answer': 'Yes, it looks almost new after months of outdoor use, demonstrating its ability to withstand heavy loads.',
#   'chunk_id': '68'},
#  {'question': 'How durable is the heavy duty extension cord for using power tools?',
#   'answer': 'The heavy-duty construction means it can be used for power tools without any concerns about safety or performance.',
#   'chunk_id': '69'},
#  {'question': 'What makes this extension cord easy to see in a cluttered garage?',
#   'answer': 'The bright orange color ensures visibility, making it easy to find in a garage.',
#   'chunk_id': '69'},
#  {'question': 'How durable is the Heavy Duty Extension Cord?',
#   'answer': 'The Heavy Duty Extension Cord has reinforced connections that provide enhanced durability, making it ideal for rough handling on construction sites.',
#   'chunk_id': '70'},
#  {'question': 'Can I plug in multiple devices with the Heavy Duty Extension Cord?',
#   'answer': 'Yes, the Heavy Duty Extension Cord features a triple outlet head that allows multiple devices, like a saw, drill, and radio, to be plugged in simultaneously without any issues.',
#   'chunk_id': '70'},
#  {'question': 'How many devices can I plug into this extension cord at once?',
#   'answer': 'The extension cord features a triple outlet head, allowing three devices to be connected simultaneously.',
#   'chunk_id': '71'},
#  {'question': 'Is this extension cord durable for heavy use?',
#   'answer': 'Yes, the extension cord has reinforced ends that provide enhanced durability, and it has proven to be quite durable even when accidentally yanked.',
#   'chunk_id': '71'},
#  {'question': 'What makes this Heavy Duty Extension Cord great for DIY projects?',
#   'answer': 'The triple outlet head design allows multiple tools to be connected, saving time during projects.',
#   'chunk_id': '72'},
#  {'question': 'How does the cord perform under tough conditions?',
#   'answer': 'The heavy-duty insulation has withstood being run over by wheeled equipment without any damage.',
#   'chunk_id': '72'},
#  {'question': 'How durable is the heavy duty extension cord?',
#   'answer': 'The heavy duty extension cord features reinforced connections that provide enhanced durability, making it ideal for tough environments like construction sites.',
#   'chunk_id': '73'},
#  {'question': 'Can I use multiple devices at once with this extension cord?',
#   'answer': 'Yes, the extension cord has a triple outlet head that allows multiple devices to be connected simultaneously.',
#   'chunk_id': '73'},
#  {'question': 'How long is the heavy duty extension cord?',
#   'answer': 'The cord’s length is 50 feet, making it great for reaching across the yard without needing multiple cords.',
#   'chunk_id': '74'},
#  {'question': 'What kind of protection does the cord have against damage?',
#   'answer': 'It features a heavy-duty jacket that protects the cord from cuts and abrasions, along with reinforced connections that prevent fraying or breaking easily.',
#   'chunk_id': '74'},
#  {'question': 'How does this extension cord perform in cold weather?',
#   'answer': 'The cord remains flexible even in temperatures as low as 10°F.',
#   'chunk_id': '75'},
#  {'question': 'What makes this extension cord suitable for outdoor use?',
#   'answer': 'It has a triple outlet head for multiple devices, durable reinforced ends, and a bright yellow color for visibility.',
#   'chunk_id': '75'},
#  {'question': 'How long is this Heavy Duty Extension Cord?',
#   'answer': 'The Heavy Duty Extension Cord is 100 feet long, providing plenty of flexibility for larger work areas.',
#   'chunk_id': '76'},
#  {'question': 'Is the extension cord durable enough for outdoor use?',
#   'answer': 'Yes, the extension cord has heavy-duty insulation and is UV-resistant, making it perfect for outdoor projects in the sun.',
#   'chunk_id': '76'},
#  {'question': 'How many devices can I plug into this heavy-duty extension cord at once?',
#   'answer': 'The extension cord features a triple outlet head, allowing multiple devices to be connected simultaneously.',
#   'chunk_id': '77'},
#  {'question': 'Is this extension cord strong enough for power tools?',
#   'answer': 'Yes, the cord has a 20-amp rating, providing confidence that it can handle heavy-duty tools like drills and sanders.',
#   'chunk_id': '77'},
#  {'question': 'How durable is the Heavy Duty Extension Cord?',
#   'answer': 'The extension cord is well-built with reinforced connections, ensuring it remains intact even when tugged or twisted.',
#   'chunk_id': '78'},
#  {'question': 'What features make this extension cord convenient for use with multiple tools?',
#   'answer': 'It features a triple outlet head, allowing for simple and efficient connection of multiple devices.',
#   'chunk_id': '78'},
#  {'question': 'What makes this extension cord suitable for heavy-duty use?',
#   'answer': 'The thick, rubberized jacket protects the cord from cuts and abrasions, and the reinforced ends handle rough treatment well.',
#   'chunk_id': '79'},
#  {'question': 'How long is the extension cord and why is that useful?',
#   'answer': 'The extension cord is 30 feet long, providing just the right amount of flexibility for use in a workshop.',
#   'chunk_id': '79'},
#  {'question': 'How long is this Heavy Duty Extension Cord, and is it suitable for outdoor use?',
#   'answer': 'The Heavy Duty Extension Cord is 100 feet long and is weather-resistant, making it suitable for outdoor use.',
#   'chunk_id': '80'},
#  {'question': 'Does the cord remain flexible in cold weather, and is it prone to tangling?',
#   'answer': 'Yes, the cord remains flexible even in cold weather and has never been prone to tangling.',
#   'chunk_id': '80'},
#  {'question': 'How does the extension cord handle high-powered tools?',
#   'answer': 'The heavy-duty construction means it can handle high-powered tools without overheating.',
#   'chunk_id': '81'},
#  {'question': 'What features help with visibility and safety when using the extension cord?',
#   'answer': 'It’s color-coded for visibility, which is great for preventing accidents.',
#   'chunk_id': '81'},
#  {'question': 'How durable is the Heavy Duty Extension Cord?',
#   'answer': 'The Heavy Duty Extension Cord features very thick insulation, providing excellent protection against wear and tear, and has proven to remain in top condition even after a year of use.',
#   'chunk_id': '82'},
#  {'question': 'Is the extension cord easy to use and store?',
#   'answer': "Yes, the extension cord's flexibility makes it easy to wind up, which simplifies storage and handling.",
#   'chunk_id': '82'},
#  {'question': 'How well does this heavy duty extension cord perform in bad weather?',
#   'answer': 'This extension cord performs flawlessly in harsh conditions, making it ideal for outdoor needs, even during a nasty winter storm.',
#   'chunk_id': '83'},
#  {'question': 'What wiring gauge does this extension cord have, and what does it mean for its performance?',
#   'answer': 'It features 12-gauge wiring, which ensures it can handle heavy loads without any drop in performance.',
#   'chunk_id': '83'},
#  {'question': 'How tough is the Heavy Duty Extension Cord?',
#   'answer': 'The exterior is highly durable and resistant to abrasions, showing no deterioration even after being stepped on, driven over, and left in the sun for days.',
#   'chunk_id': '84'},
#  {'question': 'Is the cord easy to handle?',
#   'answer': 'Yes, its flexibility makes it really easy to handle, even at the full 50-foot length.',
#   'chunk_id': '84'},
#  {'question': 'How well does this Heavy Duty Extension Cord handle high-draw equipment?',
#   'answer': 'This Heavy Duty Extension Cord is capable of handling high-draw equipment like table saws without any issues.',
#   'chunk_id': '85'},
#  {'question': 'Is the Heavy Duty Extension Cord easy to handle and less prone to tangling?',
#   'answer': 'Yes, the cord stays flexible and doesn’t kink up, making it easy to handle and reducing tangling.',
#   'chunk_id': '85'},
#  {'question': 'How does the Heavy Duty Extension Cord perform in tough weather conditions?',
#   'answer': 'The Heavy Duty Extension Cord performs outstandingly in rough outdoor conditions, with excellent performance even during rainstorms and under scorching sun.',
#   'chunk_id': '86'},
#  {'question': 'Is the Heavy Duty Extension Cord suitable for use in wet environments?',
#   'answer': 'Yes, the Heavy Duty Extension Cord is designed with moisture-resistant plugs and sockets, making it ideal for garden projects where water is often involved.',
#   'chunk_id': '86'},
#  {'question': 'How long is the Heavy Duty Extension Cord?',
#   'answer': 'The Heavy Duty Extension Cord is 25 feet long.',
#   'chunk_id': '87'},
#  {'question': 'Is this cord safe to use in bad weather?',
#   'answer': 'Yes, the extension cord is weather-resistant, ensuring it remains safe to use even during rain.',
#   'chunk_id': '87'},
#  {'question': 'How durable is this Heavy Duty Extension Cord?',
#   'answer': 'The extension cord features a reinforced jacket that protects it from wear and tear, ensuring durability.',
#   'chunk_id': '88'},
#  {'question': 'Is the length of this extension cord enough for outdoor use?',
#   'answer': 'Yes, the 50-foot length provides ample reach for outdoor power tools without compromising power delivery.',
#   'chunk_id': '88'},
#  {'question': 'How does this extension cord perform during outdoor use?',
#   'answer': 'This extension cord offers excellent performance in extreme conditions, ensuring reliability during outdoor projects.',
#   'chunk_id': '89'},
#  {'question': 'Is this cord easy to store, and does it tangle?',
#   'answer': 'The cord remains flexible and tangle-free, even after being coiled up for storage.',
#   'chunk_id': '89'},
#  {'question': 'How powerful is the motor on this corded electric chainsaw?',
#   'answer': 'The chainsaw has a 15-amp motor, which is incredibly powerful.',
#   'chunk_id': '90'},
#  {'question': "What's the chain maintenance feature that comes with this chainsaw?",
#   'answer': 'It has an automatic oiling system that ensures the chain runs smoothly, reducing wear and extending its life.',
#   'chunk_id': '90'},
#  {'question': 'Does this electric chainsaw make a lot of noise?',
#   'answer': 'No, the corded electric chainsaw is quieter compared to gas chainsaws.',
#   'chunk_id': '91'},
#  {'question': 'What safety features does it have?',
#   'answer': 'It has a chain brake and a low kickback bar to enhance safety.',
#   'chunk_id': '91'},
#  {'question': 'How powerful is the motor in the corded electric chainsaw?',
#   'answer': 'The motor is robust and can zip through logs up to 12 inches in diameter without any issues.',
#   'chunk_id': '92'},
#  {'question': 'Is this chainsaw comfortable to use for long periods?',
#   'answer': 'Yes, it is surprisingly light for its power, which reduces fatigue significantly, and the ergonomic handle enhances comfort during prolonged use.',
#   'chunk_id': '92'},
#  {'question': 'How does the starting process of this chainsaw compare to gas models?',
#   'answer': 'It starts up instantly, unlike gas chainsaws.',
#   'chunk_id': '93'},
#  {'question': 'What are some convenience features of this corded electric chainsaw?',
#   'answer': 'It has an automatic chain lubrication system and a cord retention hook to keep the extension cord secure.',
#   'chunk_id': '93'},
#  {'question': 'How powerful is the motor in this corded electric chainsaw?',
#   'answer': 'The chainsaw has a 12-amp motor that provides plenty of power for a variety of tasks.',
#   'chunk_id': '94'},
#  {'question': 'What safety features does this chainsaw have?',
#   'answer': 'It includes a chain brake and a low kickback chain, which enhance safety while operating.',
#   'chunk_id': '94'},
#  {'question': 'How powerful is the motor on this corded electric chainsaw?',
#   'answer': 'It has a 15-amp motor that powers through thick branches effortlessly.',
#   'chunk_id': '95'},
#  {'question': 'Is the chainsaw easy to maintain?',
#   'answer': 'Yes, the chain lubrication system works well and the tension can be adjusted without tools.',
#   'chunk_id': '95'},
#  {'question': 'How does the weight of this electric chainsaw compare to gas models?',
#   'answer': "It's much lighter than gas models, making it easier to handle, especially during extended use.",
#   'chunk_id': '96'},
#  {'question': 'What features contribute to the safety and maintenance of this chainsaw?',
#   'answer': 'It has a chain brake system for safety, along with an automatic oiling system and tool-free chain tensioning for simple maintenance.',
#   'chunk_id': '96'},
#  {'question': 'How powerful is the motor on this corded electric chainsaw?',
#   'answer': 'The chainsaw has a powerful 15-amp motor that cuts through branches and logs with minimal effort.',
#   'chunk_id': '97'},
#  {'question': 'Is the chainsaw easy to maintain in terms of chain lubrication?',
#   'answer': 'Yes, the chainsaw features an automatic oiling system that keeps the chain well-lubricated.',
#   'chunk_id': '97'},
#  {'question': 'How effective is the 16-inch bar on this chainsaw for tackling branches and logs?',
#   'answer': 'The 16-inch bar is capable of handling most downed branches and logs, making it quite effective for storm cleanup.',
#   'chunk_id': '98'},
#  {'question': 'What safety features does the corded electric chainsaw have?',
#   'answer': 'It includes a chain brake and a low kickback bar, which are excellent safety features.',
#   'chunk_id': '98'},
#  {'question': 'How powerful is the motor on the corded electric chainsaw?',
#   'answer': 'The chainsaw features a 12-amp motor, providing ample power for cutting through thick logs.',
#   'chunk_id': '99'},
#  {'question': 'What features make the chainsaw easy to use for a long time?',
#   'answer': 'Its lightweight design significantly reduces fatigue, and it also has automatic lubrication and tool-free tension adjustment.',
#   'chunk_id': '99'},
#  {'question': "How's the performance of the 16-inch blade in yard work tasks?",
#   'answer': 'The 16-inch blade is perfect for trimming branches and cutting firewood, making it suitable for small to medium yard tasks.',
#   'chunk_id': '100'},
#  {'question': 'What kind of maintenance does this chainsaw require for optimal use?',
#   'answer': 'It has an automatic oiling system that keeps the blade running smoothly, ensuring less manual maintenance and extended life of the blade.',
#   'chunk_id': '100'},
#  {'question': 'How easy is it to use this cords chainsaw?',
#   'answer': "It's easy to start and you don't have to deal with the noise and fumes of a gas chainsaw.",
#   'chunk_id': '101'},
#  {'question': 'What maintenance feature does this chainsaw have that helps with performance?',
#   'answer': 'The automatic oiling system works flawlessly, keeping the blade in excellent condition.',
#   'chunk_id': '101'},
#  {'question': 'How powerful is the motor in this corded electric chainsaw?',
#   'answer': 'The chainsaw features a 14.5-amp motor, which provides significant power for cutting through thick logs.',
#   'chunk_id': '102'},
#  {'question': 'What maintenance feature does this chainsaw have?',
#   'answer': 'It has an automatic oiling system that reduces maintenance and ensures smooth operation.',
#   'chunk_id': '102'},
#  {'question': 'How quiet is this electric chainsaw compared to gas-powered models?',
#   'answer': 'This electric chainsaw is much quieter than traditional gas-powered models.',
#   'chunk_id': '103'},
#  {'question': 'What features should I know about for maintaining the blade?',
#   'answer': 'It has an automatic oiling system that ensures smooth operation and extends the life of the blade.',
#   'chunk_id': '103'},
#  {'question': 'How does the automatic oiling feature benefit the chainsaw?',
#   'answer': 'The automatic oiling feature ensures smooth operation and helps extend the life of the blade.',
#   'chunk_id': '104'},
#  {'question': 'Is the chain tensioning system easy to work with?',
#   'answer': 'Yes, the chain tensioning system is easy to adjust, making it user-friendly.',
#   'chunk_id': '104'},
#  {'question': 'How does the automatic oiling system benefit the chainsaw?',
#   'answer': 'The automatic oiling system ensures smooth operation and extends the life of the blade, preventing it from seizing up.',
#   'chunk_id': '105'},
#  {'question': 'What safety features does the Corded Electric Chainsaw have?',
#   'answer': 'It includes commendable safety features such as a chain brake.',
#   'chunk_id': '105'},
#  {'question': 'How does the chainsaw handle thick branches?',
#   'answer': 'The motor is robust and it takes no time to get through thick branches.',
#   'chunk_id': '106'},
#  {'question': "What features help maintain the chainsaw's operation?",
#   'answer': 'It has an automatic oiling system and an easy-to-use chain tensioner.',
#   'chunk_id': '106'},
#  {'question': 'How well does the chainsaw handle after a storm?',
#   'answer': "It's held up wonderfully for clearing fallen trees after a storm.",
#   'chunk_id': '107'},
#  {'question': 'Is the chainsaw environmentally friendly?',
#   'answer': "Yes, it's nice not dealing with gas or fumes.",
#   'chunk_id': '107'},
#  {'question': 'How does the automatic oiling system work for this chainsaw?',
#   'answer': 'The automatic oiling system ensures smooth operation and helps to extend the life of the blade.',
#   'chunk_id': '108'},
#  {'question': 'Is this corded electric chainsaw good for homeowners?',
#   'answer': "Yes, it's perfect for homeowners looking to maintain their yard without the hassle of gas and emissions.",
#   'chunk_id': '108'},
#  {'question': 'What are some safety features of the corded electric chainsaw?',
#   'answer': 'The chainsaw has fantastic safety features including an automatic oiler and a chain brake.',
#   'chunk_id': '109'},
#  {'question': 'How does this chainsaw compare to gas-powered ones?',
#   'answer': "It's much more convenient than the gas-powered chainsaws, handling everything from trimming to felling small trees without the hassle of gas and emissions.",
#   'chunk_id': '109'},
#  {'question': 'How safe is the Corded Electric Chainsaw while using it?',
#   'answer': 'The chainsaw is equipped with a safety switch and a kickback guard, providing an added layer of security for safe handling.',
#   'chunk_id': '110'},
#  {'question': 'Can it handle tough cutting jobs like thick branches?',
#   'answer': 'Yes, it is incredibly powerful and cuts through thick branches and logs with ease, making it suitable for trimming trees and cutting firewood.',
#   'chunk_id': '110'},
#  {'question': 'How does this chainsaw handle cutting through different types of wood?',
#   'answer': 'It cuts through both small branches and larger logs with ease.',
#   'chunk_id': '111'},
#  {'question': 'What safety features does this chainsaw have?',
#   'answer': 'It is equipped with a safety switch and a kickback guard for secure handling while cutting.',
#   'chunk_id': '111'},
#  {'question': 'How well does the chainsaw perform overall?',
#   'answer': 'The Corded Electric Chainsaw performs excellently, running smoothly and allowing users to complete tasks efficiently, such as trimming an entire backyard in just one afternoon.',
#   'chunk_id': '112'},
#  {'question': 'Is the chainsaw safe to use?',
#   'answer': 'Yes, it features a kickback guard that enhances safety by preventing unexpected movements during use.',
#   'chunk_id': '112'},
#  {'question': 'How easy is it to use this corded electric chainsaw?',
#   'answer': 'The chainsaw is very user-friendly and makes outdoor tasks much easier.',
#   'chunk_id': '113'},
#  {'question': 'What are the safety features of this chainsaw?',
#   'answer': 'It is equipped with a safety switch and a kickback guard, providing top-notch safety during use.',
#   'chunk_id': '113'},
#  {'question': 'How sturdy is the Corded Electric Chainsaw during use?',
#   'answer': 'The build quality is excellent, and it feels very sturdy in hand.',
#   'chunk_id': '114'},
#  {'question': 'Is the chainsaw easy to handle?',
#   'answer': 'The chainsaw is relatively lightweight compared to other models, making it easier to maneuver.',
#   'chunk_id': '114'},
#  {'question': 'How powerful is this Corded Electric Chainsaw for cutting dense wood?',
#   'answer': "It's incredibly powerful, allowing for easy cutting through dense wood.",
#   'chunk_id': '115'},
#  {'question': 'What safety features does this chainsaw have?',
#   'answer': 'It is equipped with a safety switch and a kickback guard, ensuring secure handling while cutting.',
#   'chunk_id': '115'},
#  {'question': 'How does the chainsaw handle kickback when cutting?',
#   'answer': 'The kickback guard on this chainsaw works brilliantly to prevent kickback.',
#   'chunk_id': '116'},
#  {'question': 'What are the benefits of the corded design of this chainsaw?',
# ...
#   'chunk_id': '459'},
#  {'question': 'How durable are the screwdrivers in this set?',
#   'answer': 'The screwdrivers are incredibly durable, made from high-quality steel, and show no issues with bending or chipping, even with heavy use.',
#   'chunk_id': '460'},
#  {'question': 'What features make handling screws easier with this screwdriver set?',
#   'answer': 'The set includes magnetic tips which facilitate easy handling of screws, especially in awkward or hard-to-reach places.',
#   'chunk_id': '460'},
#  {'question': 'How durable is the screwdriver set?',
#   'answer': 'The screwdriver set is crafted from high-quality steel, ensuring durability and resistance to wear over time.',
#   'chunk_id': '461'},
#  {'question': 'What features help with using screws easily?',
#   'answer': 'The screwdriver set features magnetic tips that make handling screws easier, especially when working alone.',
#   'chunk_id': '461'},
#  {'question': 'How durable is the screwdriver set?',
#   'answer': 'The screwdriver set is crafted from high-quality steel, making it extremely durable and resistant to wear over time. It shows no signs of wear even after extensive use.',
#   'chunk_id': '462'},
#  {'question': 'What features make the screwdriver set easy to use?',
#   'answer': 'The set includes magnetic tips that allow for easy handling of screws, and the handles are designed for comfort and provide a great grip, which is appreciated during longer projects.',
#   'chunk_id': '462'},
#  {'question': 'How durable is the screwdriver set?',
#   'answer': 'The screwdriver set is crafted from high-quality steel, making it built for durability and resistance to wear over time.',
#   'chunk_id': '463'},
#  {'question': 'What are the benefits of the magnetic tips?',
#   'answer': 'The magnetic tips significantly reduce the hassle of aligning screws, allowing for easy handling of screws.',
#   'chunk_id': '463'},
#  {'question': 'How durable is the screwdriver set?',
#   'answer': 'The screwdriver set is crafted from high-quality steel, built for durability and resistance to wear over time, showing no signs of rust or wear despite frequent use.',
#   'chunk_id': '464'},
#  {'question': 'What feature helps with handling screws easily?',
#   'answer': 'The set includes strong and reliable magnetic tips that make it easier to insert and remove screws, even in tricky spots.',
#   'chunk_id': '464'},
#  {'question': 'How durable are the screwdrivers in this set based on user experience?',
#   'answer': 'The screwdrivers are well-made and have remained in great shape after several months of use, even for both light and heavy tasks.',
#   'chunk_id': '465'},
#  {'question': 'What features make this screwdriver set easy to use?',
#   'answer': 'The rotating case makes it easy to find the right size screwdriver without hassle.',
#   'chunk_id': '465'},
#  {'question': 'What makes the screwdriver set easy to carry around?',
#   'answer': 'The compact design allows it to fit comfortably in a tool belt without being bulky.',
#   'chunk_id': '466'},
#  {'question': 'How does the set keep tools organized?',
#   'answer': 'It features a rotating case that helps keep everything organized.',
#   'chunk_id': '466'},
#  {'question': 'How portable is this screwdriver set?',
#   'answer': 'The screwdriver set is small enough to carry around in a pocket and comes with a rotating case for easy transport.',
#   'chunk_id': '467'},
#  {'question': 'Does the set have a variety of sizes?',
#   'answer': 'Yes, the set includes a variety of sizes, allowing it to handle any screw without issues.',
#   'chunk_id': '467'},
#  {'question': 'How durable is the screwdriver set?',
#   'answer': 'The rotating case is quite sturdy and has not cracked even after being dropped a few times.',
#   'chunk_id': '468'},
#  {'question': 'Is the screwdriver set comfortable to use?',
#   'answer': 'Yes, the handles are ergonomically designed, making them comfortable for extended use.',
#   'chunk_id': '468'},
#  {'question': 'How compact is the screwdriver set?',
#   'answer': 'The screwdriver set is compact enough to easily store in a kitchen drawer or car glove box.',
#   'chunk_id': '469'},
#  {'question': 'What makes it easy to select a screwdriver from this set?',
#   'answer': 'The rotating case allows for quick selection of the screwdriver needed without fumbling around.',
#   'chunk_id': '469'},
#  {'question': 'How does this screwdriver set handle storage and transport?',
#   'answer': 'The screwdriver set comes with a rotating case that is compact and fits nicely in a laptop bag without taking up too much space.',
#   'chunk_id': '470'},
#  {'question': 'What features make this screwdriver set suitable for small screws?',
#   'answer': 'It has precision tips that are ideal for small screws, along with a magnetic feature to ensure screws are not lost during repairs.',
#   'chunk_id': '470'},
#  {'question': 'What features make this screwdriver set easy to use?',
#   'answer': 'The screwdriver set has a rotating case for easy storage and transport, and the screwdrivers have comfortable, non-slip grips.',
#   'chunk_id': '471'},
#  {'question': 'How durable is the screwdriver set for various tasks?',
#   'answer': 'The screwdrivers are made of high-quality steel and have held up well for tasks like assembling furniture, fixing appliances, and car repairs.',
#   'chunk_id': '471'},
#  {'question': 'What makes this screwdriver set easy to use and carry around?',
#   'answer': 'The screwdriver set features a rotating case that allows easy access to the tools and enhances portability.',
#   'chunk_id': '472'},
#  {'question': 'Is the screwdriver set designed to withstand damage?',
#   'answer': 'Yes, the case is durable and can withstand drops, making it reliable for various conditions.',
#   'chunk_id': '472'},
#  {'question': 'How does the rotating case benefit the screwdriver set?',
#   'answer': 'The rotating case keeps everything in place and easily accessible.',
#   'chunk_id': '473'},
#  {'question': 'What are the main features of the screwdrivers in this set?',
#   'answer': 'The screwdrivers are robust, and the handles are comfortable to hold.',
#   'chunk_id': '473'},
#  {'question': "How's the quality of the screwdrivers in this set?",
#   'answer': 'The screwdrivers are made from durable materials and have solid grips, making their quality impressive.',
#   'chunk_id': '474'},
#  {'question': 'What makes this screwdriver set easy to use?',
#   'answer': 'The rotating case keeps all the screwdrivers organized and easy to access, enhancing usability.',
#   'chunk_id': '474'},
#  {'question': 'How well does the adjustable jaw fit different pipes?',
#   'answer': 'The adjustable jaw fits perfectly on various pipe sizes, from small household pipes to hefty industrial ones.',
#   'chunk_id': '475'},
#  {'question': 'Is this pipe wrench durable for heavy use?',
#   'answer': "Its robust construction means it hasn't worn out even after months of heavy use.",
#   'chunk_id': '475'},
#  {'question': 'How sturdy is the pipe wrench?',
#   'answer': 'The pipe wrench has a solid build that feels sturdy and reliable.',
#   'chunk_id': '476'},
#  {'question': 'Is the jaw mechanism easy to adjust?',
#   'answer': 'Yes, the adjustable jaw mechanism is smooth and easy to use, allowing for quick adjustments.',
#   'chunk_id': '476'},
#  {'question': 'How does the jaw grip of this pipe wrench perform under pressure?',
#   'answer': "The jaw grip is firm and doesn't slip, even under high pressure.",
#   'chunk_id': '477'},
#  {'question': 'What features make this pipe wrench user-friendly for size adjustments?',
#   'answer': 'It has markings on the handle for quick size adjustments, which saves time.',
#   'chunk_id': '477'},
#  {'question': 'How does the pipe wrench feel in terms of weight and construction?',
#   'answer': 'It feels like a true professional tool and has a robust construction that ensures reliable performance.',
#   'chunk_id': '478'},
#  {'question': 'Can this pipe wrench handle different sizes of pipes?',
#   'answer': 'Yes, it features an excellent adjustability range for gripping a variety of pipe sizes.',
#   'chunk_id': '478'},
#  {'question': 'How adjustable is the jaw on this pipe wrench?',
#   'answer': 'The easy-to-adjust jaw is perfect for tackling different pipe diameters without any hassle.',
#   'chunk_id': '479'},
#  {'question': 'Is this pipe wrench durable or does it feel cheap?',
#   'answer': "Its heavy-duty build ensures durability, and it doesn't leave any marks on the pipes, unlike cheaper wrenches.",
#   'chunk_id': '479'},
#  {'question': 'How well does the adjustable jaw work on this pipe wrench?',
#   'answer': 'The adjustable jaw mechanism works smoothly and provides a firm grip on pipes.',
#   'chunk_id': '480'},
#  {'question': 'Is the pipe wrench sturdy enough for intense jobs?',
#   'answer': 'Yes, its robust construction ensures reliable performance for both household plumbing and more intense mechanical tasks.',
#   'chunk_id': '480'},
#  {'question': 'How well does the adjustable jaw work on this pipe wrench?',
#   'answer': 'The adjustable jaw is easy to operate and locks pipes securely in place.',
#   'chunk_id': '481'},
#  {'question': 'Is this pipe wrench built to last?',
#   'answer': 'Yes, it has a robust build quality that promises longevity.',
#   'chunk_id': '481'},
#  {'question': 'How does the pipe wrench handle different pipe sizes?',
#   'answer': 'The adjustable jaw allows for precise fitting on various pipe sizes, holding them without slipping.',
#   'chunk_id': '482'},
#  {'question': 'Is the pipe wrench comfortable to use for long projects?',
#   'answer': 'Yes, it feels good in the hand and has a textured handle that provides a firm grip.',
#   'chunk_id': '482'},
#  {'question': 'What makes this pipe wrench stand out from others?',
#   'answer': 'It features superior construction, an easy-to-set adjustable jaw, and teeth that securely bite into pipes to avoid slippage.',
#   'chunk_id': '483'},
#  {'question': 'Is this pipe wrench suitable for different types of jobs?',
#   'answer': 'Yes, it has proven to be reliable and versatile for both residential and commercial settings.',
#   'chunk_id': '483'},
#  {'question': 'How durable is this pipe wrench?',
#   'answer': 'The heavy-duty construction assures it will last for years.',
#   'chunk_id': '484'},
#  {'question': 'Can this pipe wrench handle different sizes of pipes?',
#   'answer': 'Yes, the adjustable jaw is versatile enough to handle different pipe sizes quickly.',
#   'chunk_id': '484'},
#  {'question': "How's the grip on this pipe wrench?",
#   'answer': 'The grip is incredibly comfortable, allowing for extended use without hand fatigue.',
#   'chunk_id': '485'},
#  {'question': 'Is the pipe wrench heavy or lightweight?',
#   'answer': 'It has a lightweight design, making it easy to carry around without feeling like a burden.',
#   'chunk_id': '485'},
#  {'question': 'How does the grip feel on this pipe wrench?',
#   'answer': 'The pipe wrench features an ergonomic grip that makes it easy to handle.',
#   'chunk_id': '486'},
#  {'question': 'Is this pipe wrench good for heavy-duty tasks?',
#   'answer': 'Despite being lightweight, the pipe wrench feels sturdy and reliable, making it suitable for all-day work.',
#   'chunk_id': '486'},
#  {'question': 'What makes this pipe wrench effective for old pipes?',
#   'answer': 'The non-slip teeth provide a secure hold on old, corroded pipes.',
#   'chunk_id': '487'},
#  {'question': 'Is the pipe wrench comfortable to use during long jobs?',
#   'answer': 'Yes, it features an excellent comfort grip that reduces strain.',
#   'chunk_id': '487'},
#  {'question': 'How lightweight is this pipe wrench for long tasks?',
#   'answer': 'The lightweight build is ideal for extended use.',
#   'chunk_id': '488'},
#  {'question': 'Does this pipe wrench have a good grip?',
#   'answer': 'The comfortable grip is a lifesaver and the non-slip teeth work exceptionally well, even on wet and greasy pipes.',
#   'chunk_id': '488'},
#  {'question': 'How does the grip on this pipe wrench feel?',
#   'answer': 'The comfort grip is superb.',
#   'chunk_id': '489'},
#  {'question': 'Is the pipe wrench heavy?',
#   'answer': 'The overall design is lightweight yet sturdy.',
#   'chunk_id': '489'},
#  {'question': 'How does the pipe wrench feel during use?',
#   'answer': 'It has an ergonomic grip that is very comfortable, even during prolonged use.',
#   'chunk_id': '490'},
#  {'question': 'What makes this pipe wrench stand out for plumbing tasks?',
#   'answer': 'Its lightweight design makes it easy to maneuver in tight spaces, and the non-slip teeth provide a strong hold on pipes without causing damage.',
#   'chunk_id': '490'},
#  {'question': 'How does the pipe wrench feel in hand?',
#   'answer': 'It has a comfortable grip that fits perfectly in hand and significantly reduces strain.',
#   'chunk_id': '491'},
#  {'question': 'Is the pipe wrench easy to use for long periods?',
#   'answer': 'Yes, its lightweight design allows for all-day use without feeling weighed down.',
#   'chunk_id': '491'},
#  {'question': 'Is this pipe wrench easy to use for long periods?',
#   'answer': 'Yes, the lightweight design and comfortable grip make it easy to use for long periods.',
#   'chunk_id': '492'},
#  {'question': 'How effective are the teeth on this pipe wrench?',
#   'answer': 'The non-slip teeth are very effective, gripping pipes securely without slipping.',
#   'chunk_id': '492'},
#  {'question': 'How comfortable is the grip on this pipe wrench?',
#   'answer': 'The grip is extremely comfortable, reducing hand fatigue during extended use.',
#   'chunk_id': '493'},
#  {'question': 'Is this pipe wrench lightweight?',
#   'answer': 'Yes, it has a lightweight build perfect for jobs requiring a lot of movement.',
#   'chunk_id': '493'},
#  {'question': 'How does the design of the pipe wrench feel during use?',
#   'answer': 'The pipe wrench features a comfort grip that feels great in hand, making it suitable for all-day work.',
#   'chunk_id': '494'},
#  {'question': "What's the grip like on this pipe wrench?",
#   'answer': 'The pipe wrench has a non-slip grip that provides a firm hold on pipes, whether they are old and rusty or brand new.',
#   'chunk_id': '494'},
#  {'question': 'How durable is the pipe wrench in humid conditions?',
#   'answer': 'The pipe wrench has a rust-resistant coating that holds up extremely well in humid environments.',
#   'chunk_id': '495'},
#  {'question': 'What features does the pipe wrench have for grip adjustment?',
#   'answer': 'The pipe wrench features dual jaws, allowing for reversing the grip as needed.',
#   'chunk_id': '495'},
#  {'question': 'How durable is the pipe wrench in wet conditions?',
#   'answer': 'The pipe wrench is coated with rust-resistant material, ensuring durability even in damp conditions.',
#   'chunk_id': '496'},
#  {'question': 'What feature of the pipe wrench allows for easier grip adjustments?',
#   'answer': 'Its dual jaws allow for reversing the grip as needed.',
#   'chunk_id': '496'},
#  {'question': 'Is this pipe wrench resistant to rust?',
#   'answer': 'Yes, it has a rust-resistant coating, ensuring durability even in damp conditions.',
#   'chunk_id': '497'},
#  {'question': 'Can you easily use this wrench in tight spaces?',
#   'answer': 'Yes, the dual jaws allow for reversing the grip, making it easy to use in tight spaces.',
#   'chunk_id': '497'},
#  {'question': 'How durable is the pipe wrench?',
#   'answer': 'The pipe wrench is durable due to its rust-resistant coating, ensuring longevity even in damp conditions.',
#   'chunk_id': '498'},
#  {'question': 'What features does the pipe wrench have for ease of use?',
#   'answer': 'It has dual jaws that make reversing the grip straightforward.',
#   'chunk_id': '498'},
#  {'question': 'Is this pipe wrench resistant to rust?',
#   'answer': 'Yes, this pipe wrench is coated with rust-resistant material, ensuring durability even in damp conditions.',
#   'chunk_id': '499'},
#  {'question': 'How does the dual jaws feature work on this wrench?',
#   'answer': 'The dual jaws allow for reversing the grip as needed, making it significantly easier to use compared to other wrenches.',
#   'chunk_id': '499'},
#  ...]

# %% [markdown]
# ## Set Up Evaluation
#
# Load the evaluation questions into a structured format.

# %%
from pydantic import BaseModel


class EvalQuestion(BaseModel):
    question: str
    answer: str
    chunk_id: str


eval_questions = [EvalQuestion(**question) for question in synthetic_questions]

# %% [markdown]
# Build a simple search function

# %%
def run_simple_request(q: EvalQuestion, n_return_vals=5):
    results = (
        reviews_table.search(q.question).select(["id"]).limit(n_return_vals).to_list()
    )
    return [str(q.chunk_id) == str(r["id"]) for r in results]

# %% [markdown]
# Now do the benchmarking. For simplicity, we just compare retrieval sizes with a simple semantic search in this cell.

# %%
def score(hits):
    # This implementation assumes
    n_retrieval_requests = len(hits)
    total_retrievals = sum(len(l) for l in hits)
    true_positives = sum(sum(sublist) for sublist in hits)
    precision = true_positives / total_retrievals if total_retrievals > 0 else 0
    recall = true_positives / n_retrieval_requests if n_retrieval_requests > 0 else 0
    return {"precision": precision, "recall": recall}


def score_simple_search(n_to_retrieve: List[int]) -> Dict[str, float]:
    # parallelize to speed this up 5-10X
    with ThreadPoolExecutor() as executor:
        hits = list(
            executor.map(lambda q: run_simple_request(q, n_to_retrieve), eval_questions)
        )
    return score(hits)


k_to_retrieve = [5, 10, 20]
scores = pd.DataFrame([score_simple_search(n) for n in k_to_retrieve])
scores["n_retrieved"] = k_to_retrieve
scores
# Out:
#    precision    recall  n_retrieved
# 0   0.101410  0.507048            5
# 1   0.070749  0.707489           10
# 2   0.044361  0.887225           20

# %% [markdown]
# If you have Cohere set up, you can compare these results to the results with a reranker.
#
# If you aren't familiar with rerankers, don't worry. We will cover them in upcoming lessons.

# %%
try:
    import cohere
    cohere_api_key = os.environ["COHERE_API_KEY"]


    def run_reranked_request(q: EvalQuestion, n_return_vals=5, n_to_rerank=50) -> List[bool]:
        # First, get more results than we need
        initial_results = reviews_table.search(q.question) \
            .select(["id", "review"]) \
            .limit(n_to_rerank) \
            .to_list()
        
        # Prepare texts for reranking
        texts = [r["review"] for r in initial_results]
        
        # Rerank using Cohere
        co = cohere.Client(cohere_api_key)
        reranked = co.rerank(
            query=q.question,
            documents=texts,
            top_n=n_return_vals
        )
        
        # Map reranked results back to original IDs
        reranked_ids = [initial_results[r.index]["id"] for r in reranked.results]
        return [str(q.chunk_id) == str(r) for r in reranked_ids]

    def score_reranked_search(n_to_retrieve: List[int], n_to_rerank: int = 50) -> Dict[str, float]:
        with ThreadPoolExecutor() as executor:
            hits = list(executor.map(
                lambda q: run_reranked_request(q, n_to_retrieve, n_to_rerank), 
                eval_questions
            ))
        return score(hits)


    k_to_retrieve = [5, 10, 20]
    reranked_scores = pd.DataFrame([score_reranked_search(n) for n in k_to_retrieve])
    reranked_scores["n_retrieved"] = k_to_retrieve
    print(reranked_scores)
except Exception as e:
    print(f"Cohere is not set up. Cannot run reranker.")
# Out:
#    precision    recall  n_retrieved
# 0   0.125286  0.626432            5
# 1   0.081189  0.811894           10
# 2   0.046938  0.938767           20
